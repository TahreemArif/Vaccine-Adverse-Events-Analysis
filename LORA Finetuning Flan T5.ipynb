# %%
# !pip install transformers datasets evaluate accelerate torch sacremoses peft gdown openpyxl
# !pip install pyarrow==15.0.2
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.9)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 12.9 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.1 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 50.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, sacremoses, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 sacremoses-0.1.1 xxhash-3.5.0
# Collecting pyarrow==15.0.2
#   Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<2,>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow==15.0.2) (1.26.4)
# Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 53.4 MB/s eta 0:00:00
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
# Successfully installed pyarrow-15.0.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import os
import json
import pandas as pd
import numpy as np

from ast import literal_eval

# %%
base_dir = '/content/drive/MyDrive/NLP/vaers_analysis'
data_dir = os.path.join(base_dir, 'data')
results_dir = os.path.join(base_dir, 'results')
models_dir = os.path.join(base_dir, 'models')
runs_dir = os.path.join(base_dir, 'runs')

# %%
data = pd.read_csv(os.path.join(data_dir, 'train_vaers_data.csv'))
data['symptoms'] = data['symptoms'].apply(literal_eval)
data['ordered_symptoms'] = data['ordered_symptoms'].apply(literal_eval)
data.head()
# Out:
#    vaers_id  year         vax_type vax_manu  \
# 0   1563876  2021  COVID19          MODERNA
# 1   1121903  2021  COVID19          MODERNA
# 2   2501590  2022  COVID19          MODERNA
# 3   1228802  2021  COVID19          MODERNA
# 4   1666419  2021  COVID19          MODERNA
#
#                                         symptom_text  \
# 0  increase in blood pressure; Knot on right arm;...
# 1  The day after the vaccine, I had extreme fatig...
# 2  Narrative: Patient was not previously COVID-19...
# 3  Several minutes after receiving 1st dose of Mo...
# 4  Patient is an 86-year-old woman with a history...
#
#                                             symptoms  \
# 0  [Blood pressure increased, Muscle twitching, U...
# 1  [Chills, Fatigue, Headache, Injection site pai...
# 2                     [Death, Fall, Wheelchair user]
# 3  [Fall, Loss of consciousness, Syncope, Unrespo...
# 4  [Aphasia, COVID-19, Confusional state, Mental ...
#
#                                     ordered_symptoms  report_length  \
# 0  [Urticaria, Vaccination site mass, Muscle twit...            234
# 1  [Injection site pain, Rash erythematous, Fatig...             96
# 2                     [Fall, Wheelchair user, Death]             98
# 3  [Loss of consciousness, Syncope, Unresponsive ...            112
# 4  [Respiratory symptom, COVID-19, SARS-CoV-2 tes...            212
#
#    num_symptoms
# 0             4
# 1             7
# 2             3
# 3             4
# 4             8

# %% [markdown]
# ## Data Preparation for PEFT:

# %%
import os
import json
import math
import pandas as pd
import matplotlib.pyplot as plt

import torch
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    TrainingArguments,
    Trainer
)

from datasets import Dataset, DatasetDict

# %%
model_name = 'flan-t5-large'
model_vendor = 'google'
output_dir = os.path.join(runs_dir, model_name)
peft_model_path = os.path.join(models_dir, model_name)

# %%
def create_prompts(row):
    instruction = 'Order the symptoms in chronological order based on the timeline implied in the text. Think step by step to determine the timeline for each symptom.'
    prompt = f"{instruction}\n\nText: {row['symptom_text']}\n\nSymptoms: {row['symptoms']}\n\nOrdered Symptoms:"
    return prompt

# %%
## Convert symptoms into a string with comma separated symptoms
data['symptoms'] = data['symptoms'].apply(lambda symptoms: ', '.join(symptoms))
data['output_text'] = data['ordered_symptoms'].apply(lambda symptoms: ', '.join(symptoms))
data['input_text'] = data.apply(create_prompts, axis=1)

# %%
train_dataset = Dataset.from_dict({
    'input_text': data['input_text'].to_list(),
    'output_text': data['output_text'].to_list()
})

train_valid_spt = train_dataset.train_test_split(test_size=0.1, seed=42)

train_dataset = DatasetDict({
    'train': train_valid_spt['train'],
    'validation': train_valid_spt['test'],
})
train_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 9000
#     })
#     validation: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 1000
#     })
# })

# %% [markdown]
# ## Model Finetuning:

# %%
tokenizer = AutoTokenizer.from_pretrained(f'{model_vendor}/{model_name}')
model = AutoModelForSeq2SeqLM.from_pretrained(f'{model_vendor}/{model_name}')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
def tokenize(data, tokenizer):
  tokenized_data = tokenizer(data['input_text'], padding='max_length', max_length=1024, truncation=True, return_tensors='pt')
  tokenized_data['labels'] = tokenizer(data['output_text'], padding='max_length', max_length=128, truncation=True, return_tensors='pt').input_ids
  return tokenized_data

fn_kwargs={"tokenizer": tokenizer}
tokenized_dataset = train_dataset.map(tokenize, batched=True, fn_kwargs=fn_kwargs)
tokenized_dataset = tokenized_dataset.map(lambda examples: examples, remove_columns=['input_text', 'output_text'])
tokenized_dataset
# Out:
# Map:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 9000
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })

# %%
from peft import LoraConfig, TaskType, get_peft_model
from transformers import EarlyStoppingCallback

peft_config = LoraConfig(
    r=16,
    bias='none',
    lora_alpha=32,
    lora_dropout=0.05,
    task_type=TaskType.SEQ_2_SEQ_LM,
    #finetuning the attention layers only
    target_modules=['q', 'k', 'v']
)

peft_training_args = TrainingArguments(
    output_dir=output_dir,
    auto_find_batch_size=True,
    learning_rate=1e-3,
    num_train_epochs=10,
    max_steps=10000,
    warmup_steps=500,
    weight_decay=0.01,
    eval_strategy='steps',
    save_strategy='steps',
    logging_steps=100,
    eval_steps=100,
    save_steps=100,
    load_best_model_at_end=True
)

# %%
peft_model = get_peft_model(model, peft_config)

peft_trainer = Trainer(
    model=peft_model,
    args=peft_training_args,
    train_dataset=tokenized_dataset['train'],
    eval_dataset=tokenized_dataset['validation'],
    tokenizer=tokenizer,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=10)]  # Stop if no improvement for 10 Steps
)
# Out:
# <ipython-input-14-c32b4bc41c25>:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   peft_trainer = Trainer(
# max_steps is given, it will override any value given in num_train_epochs

# %%
peft_model.print_trainable_parameters()
# Out:
# trainable params: 7,077,888 || all params: 790,227,968 || trainable%: 0.8957

# %%
peft_trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241207_172730-y7hbwxqk</code>
# Syncing run <strong><a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface/runs/y7hbwxqk' target="_blank">/content/drive/MyDrive/NLP/vaers_analysis/runs/flan-t5-large</a></strong> to <a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface' target="_blank">https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface</a>
#  View run at <a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface/runs/y7hbwxqk' target="_blank">https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface/runs/y7hbwxqk</a>
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='1500' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1500/10000 1:27:43 < 8:17:45, 0.28 it/s, Epoch 0/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>28.130400</td>
#       <td>15.489042</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>5.619300</td>
#       <td>0.108866</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.101200</td>
#       <td>0.085434</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.096100</td>
#       <td>0.071138</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.081400</td>
#       <td>0.062982</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.090600</td>
#       <td>0.084274</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.087400</td>
#       <td>0.904031</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.094900</td>
#       <td>0.073288</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.092600</td>
#       <td>0.064791</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.081600</td>
#       <td>0.065146</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.280900</td>
#       <td>0.122985</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.126500</td>
#       <td>0.067634</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.108700</td>
#       <td>0.078863</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.109700</td>
#       <td>0.064928</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.085900</td>
#       <td>0.067431</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1500, training_loss=2.412481945037842, metrics={'train_runtime': 5265.0309, 'train_samples_per_second': 3.799, 'train_steps_per_second': 1.899, 'total_flos': 1.3959067336704e+16, 'train_loss': 2.412481945037842, 'epoch': 0.3333333333333333})

# %%
## Save the model
peft_trainer.model.save_pretrained(peft_model_path)
tokenizer.save_pretrained(peft_model_path)
# Out:
# ('/content/drive/MyDrive/NLP/vaers_analysis/models/flan-t5-large/tokenizer_config.json',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/flan-t5-large/special_tokens_map.json',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/flan-t5-large/spiece.model',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/flan-t5-large/added_tokens.json',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/flan-t5-large/tokenizer.json')

# %% [markdown]
# ## Inference:

# %%
from peft import PeftModel, PeftConfig

# %%
test_dataset = pd.read_csv(os.path.join(data_dir, 'test_vaers_data.csv'))
test_dataset['symptoms'] = test_dataset['symptoms'].apply(literal_eval)
test_dataset['ordered_symptoms'] = test_dataset['ordered_symptoms'].apply(literal_eval)
test_dataset['input_text'] = test_dataset.apply(create_prompts, axis=1)
test_dataset['output_text'] = test_dataset['ordered_symptoms'].apply(lambda symptoms: ', '.join(symptoms))
test_dataset.head()
# Out:
#    vaers_id  year         vax_type vax_manu  \
# 0   1344132  2021  COVID19          MODERNA
# 1   1842147  2021  COVID19          MODERNA
# 2   1165207  2021  COVID19          MODERNA
# 3   1618374  2021  COVID19          MODERNA
# 4   2460242  2022  COVID19          MODERNA
#
#                                         symptom_text  \
# 0  A few days after my vaccine, I noticed under t...
# 1  Period schedule on and off the chart; Increase...
# 2  within 24 hours of receiving my 2nd dose, I fi...
# 3  Side effects seem to have cleared up by the 17...
# 4  I received my first Moderna vaccine on one/14/...
#
#                                             symptoms  \
# 0                                [Blister, Erythema]
# 1  [Biopsy, Heavy menstrual bleeding, Menstrual d...
# 2  [Chills, Dry eye, Eye pain, Fatigue, Headache,...
# 3               [Headache, Vaccination complication]
# 4  [Amenorrhoea, Arthralgia, Carbohydrate antigen...
#
#                                     ordered_symptoms  report_length  \
# 0                                [Blister, Erythema]             93
# 1  [Menstrual disorder, Heavy menstrual bleeding,...            259
# 2  [Pyrexia, Chills, Headache, Myalgia, Neuralgia...            110
# 3               [Vaccination complication, Headache]            241
# 4  [Lymphadenopathy, Arthralgia, Pain in extremit...            162
#
#    num_symptoms                                         input_text  \
# 0             2  Order the symptoms in chronological order base...
# 1             4  Order the symptoms in chronological order base...
# 2             9  Order the symptoms in chronological order base...
# 3             2  Order the symptoms in chronological order base...
# 4            12  Order the symptoms in chronological order base...
#
#                                          output_text
# 0                                  Blister, Erythema
# 1  Menstrual disorder, Heavy menstrual bleeding, ...
# 2  Pyrexia, Chills, Headache, Myalgia, Neuralgia,...
# 3                 Vaccination complication, Headache
# 4  Lymphadenopathy, Arthralgia, Pain in extremity...

# %%
def batch_inference(model, tokenizer, test_prompts, batch_size=5):
    """
    Performs batch inference on a list of prompts using a pre-trained model and tokenizer.

    This function processes the prompts in batches to efficiently handle large datasets,
    tokenizes the input, and generates predictions using the model. It returns the decoded
    predicted sequences.

    Args:
        model (torch.nn.Module): The pre-trained model to use for inference (e.g., GPT, T5, etc.).
        tokenizer (PreTrainedTokenizer): The tokenizer associated with the model for encoding inputs and decoding outputs.
        test_prompts (list of str): List of input prompts to generate predictions for.
        batch_size (int, optional): The number of prompts to process in each batch. Default is 5.

    Returns:
        list of str: A list of decoded predicted sequences corresponding to the input prompts.

    Raises:
        Exception: Catches and reports errors encountered during batch processing.

    Notes:
        - The function uses GPU if available; otherwise, it defaults to CPU.
        - Each batch is tokenized with padding and truncation up to a maximum input length of 1024 tokens.
        - Model generates predictions with up to 128 new tokens using beam search with 5 beams.
        - Any exceptions during batch processing are caught, and the function proceeds with the next batch.
    """
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = model.to(device)
    predicted_sequence = []
    num_batches = math.ceil(len(test_prompts) / batch_size)

    for i in range(num_batches):
        try:
            # Prepare the batch of prompts
            batch = tokenizer(
                test_prompts[i * batch_size:(i + 1) * batch_size],
                padding='max_length',
                max_length=1024,
                truncation=True,
                return_tensors='pt'
            ).to(device)

            # Generate predictions
            encoded_sequence = model.generate(**batch, max_new_tokens=128, num_beams=5)

            # Decode the predictions
            predicted_sequence.extend(tokenizer.batch_decode(encoded_sequence, skip_special_tokens=True))

        except Exception as e:
            # Handle errors for the batch
            print(f'Error in batch {i}: {e}')
            continue

        print(f'Processed Batch: {i} successfully!!')

    return predicted_sequence

# %%
def create_eval_df(test_dataset, predicted_sequence, true_sequence_key='output_text',
                   symptom_text_key='symptom_text', prompt_key='input_text'):
    """
    Creates an evaluation DataFrame by processing true and predicted sequences from the dataset.

    Args:
        test_dataset (pd.DataFrame): The dataset containing test inputs and expected outputs.
        predicted_sequence (list): The list of predicted sequences.
        true_sequence_key (str): The column key in `test_dataset` for the true sequence. Default is 'output_text'.
        symptom_text_key (str): The column key in `test_dataset` for the symptom text. Default is 'symptom_text'.
        prompt_key (str): The column key in `test_dataset` for the prompts. Default is 'input_text'.

    Returns:
        pd.DataFrame: Processed evaluation DataFrame with cleaned true and predicted sequences.
    """
    # Create the evaluation DataFrame
    eval_df = pd.DataFrame({
        'symptom_text': test_dataset[symptom_text_key].to_list(),
        'prompt': test_dataset[prompt_key].to_list(),
        'true_sequence': test_dataset[true_sequence_key].to_list(),
        'predicted_sequence': predicted_sequence
    })

    # Process and clean the true and predicted sequences
    eval_df['true_sequence'] = eval_df['true_sequence'].apply(lambda sym: [s.strip() for s in sym.split(',')])
    eval_df['predicted_sequence'] = eval_df['predicted_sequence'].apply(lambda sym: [s.strip().strip("'\"") for s in sym.split(',')])

    return eval_df

# %% [markdown]
# ### Inference Using FlanT5-Large Without PEFT:

# %%
# Step 1: Load the pre-trained sequence-to-sequence model
base_model = AutoModelForSeq2SeqLM.from_pretrained(f'{model_vendor}/{model_name}')

## Step 2: Perform batch inference using the loaded model
predicted_sequence_wpeft = batch_inference(base_model, tokenizer, test_dataset['input_text'].to_list())

## Step 3: Create a DataFrame for evaluation
eval_df_wpeft = create_eval_df(test_dataset, predicted_sequence_wpeft)
eval_df_wpeft[['symptom_text', 'true_sequence', 'predicted_sequence']].head(10)
# Out:
# Processed Batch: 0 successfully!!
# Processed Batch: 1 successfully!!
# Processed Batch: 2 successfully!!
# Processed Batch: 3 successfully!!
# Processed Batch: 4 successfully!!
# Processed Batch: 5 successfully!!
# Processed Batch: 6 successfully!!
# Processed Batch: 7 successfully!!
# Processed Batch: 8 successfully!!
# Processed Batch: 9 successfully!!
# Processed Batch: 10 successfully!!
# Processed Batch: 11 successfully!!
# Processed Batch: 12 successfully!!
# Processed Batch: 13 successfully!!
# Processed Batch: 14 successfully!!
# Processed Batch: 15 successfully!!
# Processed Batch: 16 successfully!!
# Processed Batch: 17 successfully!!
# Processed Batch: 18 successfully!!
# Processed Batch: 19 successfully!!
# Processed Batch: 20 successfully!!
# Processed Batch: 21 successfully!!
# Processed Batch: 22 successfully!!
# Processed Batch: 23 successfully!!
# Processed Batch: 24 successfully!!
# Processed Batch: 25 successfully!!
# Processed Batch: 26 successfully!!
# Processed Batch: 27 successfully!!
# Processed Batch: 28 successfully!!
# Processed Batch: 29 successfully!!
# Processed Batch: 30 successfully!!
# Processed Batch: 31 successfully!!
# Processed Batch: 32 successfully!!
# Processed Batch: 33 successfully!!
# Processed Batch: 34 successfully!!
# Processed Batch: 35 successfully!!
# Processed Batch: 36 successfully!!
# Processed Batch: 37 successfully!!
# Processed Batch: 38 successfully!!
# Processed Batch: 39 successfully!!
# Processed Batch: 40 successfully!!
# Processed Batch: 41 successfully!!
# Processed Batch: 42 successfully!!
# Processed Batch: 43 successfully!!
# Processed Batch: 44 successfully!!
# Processed Batch: 45 successfully!!
# Processed Batch: 46 successfully!!
# Processed Batch: 47 successfully!!
# Processed Batch: 48 successfully!!
# Processed Batch: 49 successfully!!
# Processed Batch: 50 successfully!!
# Processed Batch: 51 successfully!!
# Processed Batch: 52 successfully!!
# Processed Batch: 53 successfully!!
# Processed Batch: 54 successfully!!
# Processed Batch: 55 successfully!!
# Processed Batch: 56 successfully!!
# Processed Batch: 57 successfully!!
# Processed Batch: 58 successfully!!
# Processed Batch: 59 successfully!!
# Processed Batch: 60 successfully!!
# Processed Batch: 61 successfully!!
# Processed Batch: 62 successfully!!
# Processed Batch: 63 successfully!!
# Processed Batch: 64 successfully!!
# Processed Batch: 65 successfully!!
# Processed Batch: 66 successfully!!
# Processed Batch: 67 successfully!!
# Processed Batch: 68 successfully!!
# Processed Batch: 69 successfully!!
# Processed Batch: 70 successfully!!
# Processed Batch: 71 successfully!!
# Processed Batch: 72 successfully!!
# Processed Batch: 73 successfully!!
# Processed Batch: 74 successfully!!
# Processed Batch: 75 successfully!!
# Processed Batch: 76 successfully!!
# Processed Batch: 77 successfully!!
# Processed Batch: 78 successfully!!
# Processed Batch: 79 successfully!!
# Processed Batch: 80 successfully!!
# Processed Batch: 81 successfully!!
# Processed Batch: 82 successfully!!
# Processed Batch: 83 successfully!!
# Processed Batch: 84 successfully!!
# Processed Batch: 85 successfully!!
# Processed Batch: 86 successfully!!
# Processed Batch: 87 successfully!!
# Processed Batch: 88 successfully!!
# Processed Batch: 89 successfully!!
# Processed Batch: 90 successfully!!
# Processed Batch: 91 successfully!!
# Processed Batch: 92 successfully!!
# Processed Batch: 93 successfully!!
# Processed Batch: 94 successfully!!
# Processed Batch: 95 successfully!!
# Processed Batch: 96 successfully!!
# Processed Batch: 97 successfully!!
# Processed Batch: 98 successfully!!
# Processed Batch: 99 successfully!!
#                                         symptom_text  \
# 0  A few days after my vaccine, I noticed under t...
# 1  Period schedule on and off the chart; Increase...
# 2  within 24 hours of receiving my 2nd dose, I fi...
# 3  Side effects seem to have cleared up by the 17...
# 4  I received my first Moderna vaccine on one/14/...
# 5  Patient experienced only chills; Fever; Sorene...
# 6  8 days after the first vaccine dose, I had itc...
# 7  Sore arm; Very tired; Headache; Burning sensat...
# 8  Chills; Urinating (More often); This spontaneo...
# 9  Swelling Left arm, upper Calves and legs swell...
#
#                                        true_sequence  \
# 0                                [Blister, Erythema]
# 1  [Menstrual disorder, Heavy menstrual bleeding,...
# 2  [Pyrexia, Chills, Headache, Myalgia, Neuralgia...
# 3               [Vaccination complication, Headache]
# 4  [Lymphadenopathy, Arthralgia, Pain in extremit...
# 5                         [Chills, Pyrexia, Myalgia]
# 6  [Injection site pruritus, Injection site swell...
# 7  [Burning sensation, Headache, Pain in extremit...
# 8                              [Chills, Pollakiuria]
# 9  [Peripheral swelling, Vaccination site bruisin...
#
#                                   predicted_sequence
# 0                            [['Blister, Erythema']]
# 1  [Biopsy, Heavy menstrual bleeding, Menstrual d...
# 2  [['Chills, Dry eye, Eye pain, Fatigue, Headach...
# 3  [VACCINATION COMPLICATION (Side effects seem t...
# 4  [Amenorrhoea, Arthralgia, Carbohydrate antigen...
# 5                         [Chills, Myalgia, Pyrexia]
# 6  [['Injection site erythema, Injection site ind...
# 7             [Burning sensation, Fatigue, Headache]
# 8                   [Chills, Urinating (More often)]
# 9  [['Abdominal distension, Abdominal pain upper,...

# %%
predicted_sequence_wpeft
# Out:
# ["['Blister', 'Erythema']",
#  'Biopsy, Heavy menstrual bleeding, Menstrual disorder',
#  "['Chills', 'Dry eye', 'Eye pain', 'Fatigue', 'Headache', 'Myalgia', 'Neuralgia', 'Pain']",
#  'VACCINATION COMPLICATION (Side effects seem to have cleared up by the 17th) HEADACHE (Weird burst of pain on the left side of my head)',
#  'Amenorrhoea, Arthralgia, Carbohydrate antigen 125, Lymphadenopathy, Menopausal symptoms, Menstrual disorder, Ovarian disorder, Pain in extremity, Pelvic pain, Sacral pain, Ultrasound pelvis abnormal, Uterine disorder',
#  'Chills, Myalgia, Pyrexia',
#  "['Injection site erythema', 'Injection site induration', 'Injection site swelling', 'Injection site warmth']",
#  'Burning sensation, Fatigue, Headache',
#  'Chills, Urinating (More often)',
#  "['Abdominal distension', 'Abdominal pain upper', 'Anxiety', 'Asthma', 'Fatigue', 'Headache', 'Pain in extremity', 'Vaccination site bruising']",
#  "['COVID-19', 'Cognitive disorder', 'Exposure to SARS-CoV-2', 'Hypophagia']",
#  'Magnetic resonance imaging, NEUROPATHY PERIPHERAL, Pain, Positron emission tomogram, Spinal pain',
#  "['Hypoaesthesia', 'Paraesthesia'] Approximately 5 minutes after receiving booster dose, the left side of the patient's face started tingling and felt numb. She said that this happened with the first dose, but was more intense-lasting 90 minutes, and that it did not happen with the second dose. She didn't have any obvious swelling/inflammation, redness, or difficulty moving the area. Her speech was unimpaired.",
#  "['Decreased appetite', 'Diarrhea', 'Fatigue', 'Pain in extremity', 'Vomiting']",
#  "['Dermatitis contact', 'Ear discomfort', 'Hypoacusis', 'Lymphadenopathy', 'Scab', 'Skin weeping', 'Swelling', 'Tinnitus']",
#  "['Chills', 'Diarrhea', 'Headache', 'Injection site swelling', 'Neck pain', 'Pyrexia']",
#  "['Chills', 'Myalgia', 'Nausea', 'Somnolence', 'Vaccination site rash']",
#  "['Hypoaesthesia oral', 'Influenza like illness', 'Pain in extremity']",
#  "['Anger', 'Phobia', 'Suspiciousness']",
#  'Arthralgia, Impaired work ability, Joint range of motion decreased, Loss of personal independence in daily activities, Pain, Sleep disorder',
#  "['Chills', 'Cough', 'Fatigue', 'Injection site erythema', 'Injection site pain', 'Injection site pruritus', 'Injection site swelling', 'Injection site warmth', 'Pain', 'Pyrexia', 'Sinus headache']",
#  'Fatigue, Headache, Hyperhidrosis, Oropharyngeal pain, Pain, Pain in extremity, Pyrexia, SARS-CoV-2 test positive',
#  'Arthralgia, Arthritis, Magnetic resonance imaging abnormal, Pain',
#  'PAIN IN EXTREMITY (Soreness of arm) On 05-Mar-2021, after starting mRNA-1273 (Moderna COVID-19 Vaccine) (Intramuscular) dosage was changed to 1 dosage form. On 05-Mar-2021, received second dose of mRNA-1273 (Moderna COVID-19 Vaccine) (Intramuscular) dosage was changed to 1 dosage form. On 05-Mar-2021, received second dose of mRNA-1273 (Moderna COVID-19 ',
#  "['Menstrual disorder', 'Pain', 'Pain in extremity']",
#  "['Injection site erythema', 'Injection site pruritus', 'Pruritus', 'Rash']",
#  'Bedridden, Feeling abnormal, Headache, Pyrexia',
#  '["Bell\'s palsy", "Facial paralysis", "Hypoaesthesia"]',
#  'Hypertension, Injection site erythema, Injection site pruritus, Injection site swelling',
#  "['Injection site induration', 'Injection site pruritus', 'Injection site swelling']",
#  'Erythema, Pain',
#  "['Injection site rash', 'Rash pruritic']",
#  'Condition aggravated, Tinnitus',
#  "['Hypoacusis', 'Vision blurred']",
#  "['Injection site induration', 'Injection site inflammation', 'Injection site reaction', 'Injection site swelling', 'Injection site warmth']",
#  "['Cough', 'Dizziness', 'Dysgeusia', 'Fatigue', 'Flushing', 'Headache', 'Impaired work ability', 'Oropharyngeal pain', 'Pain in jaw', 'Pyrexia', 'Throat irritation']",
#  'Dizziness, Fall, Heart rate increased',
#  '[Injection site pruritus, injection site rash, injection site swelling]',
#  'Chest discomfort, Chills, Heart rate',
#  "['Amnesia', 'Loss of consciousness', 'Seizure like phenomena']",
#  'FEELING ABNORMAL (Feeling miserable all day), HEADACHE (Headache), NAUSEA (Nausea), MYALGIA (Body ache), FATIGUE (Fatigue) and PYREXIA (Fever)',
#  'PAIN IN EXTREMITY (arm pain), MYALGIA (body ache) and FATIGUE (fatigue)',
#  "['Ear discomfort', 'Mechanical urticaria', 'Pruritus', 'Skin irritation', 'Urticaria']",
#  "['Chills', 'Discomfort', 'Nervousness', 'Psychomotor hyperactivity', 'Restlessness', 'Sleep disorder', 'Thinking abnormal']",
#  "['Abdominal discomfort', 'Lymphadenopathy', 'Neck pain', 'Oral candidiasis', 'Peripheral swelling']",
#  'Erythema',
#  "['COVID-19', 'Dizziness', 'Fall', 'Headache', 'Imaging procedure abnormal', 'Neck pain', 'Oropharyngeal pain', 'Pneumonia']",
#  "['Asthenia', 'Dizziness', 'Headache', 'Heart rate increased', 'Hyperhidrosis', 'Impaired driving ability']",
#  'PAIN IN EXTREMITY (arm pain/same symptoms), PYREXIA (a little bit of a fever), FATIGUE (fatigue) and MYALGIA (body aches)',
#  'Dysgraphia, Tremor, X-ray abnormal',
#  "['Rash erythematous', 'Vaccination site erythema', 'Vaccination site reaction']",
#  "['Blood pressure increased', 'Dizziness']",
#  'Haemorrhage, Pruritus, Rash macular, Scratch, Urticaria',
#  "['Anxiety', 'Depression', 'Seizure like phenomena', 'Tearfulness']",
#  'Death, Malaise, SARS-CoV-2 test positive',
#  'PAIN IN EXTREMITY (sore arm), HEADACHE (Headache) and NAUSEA (Extreme Nausea) On 24-Feb-2021, the patient experienced HEADACHE (Headache) and NAUSEA (Extreme Nausea) On 10-Mar-2021, the patient experienced PAIN IN EXTREMITY (sore arm)',
#  'Cough, Illness, Pyrexia, Vomiting',
#  "['Dry eye', 'Eye pain', 'Photopsia', 'Vision blurred']",
#  "['Dizziness', 'Nausea']",
#  "['Asthenia', 'Dizziness', 'Ear discomfort', 'Extrasystoles', 'Headache']",
#  "['Dizziness', 'Fall']",
#  "['Injection site erythema', 'Injection site pain', 'Injection site swelling', 'Injection site warmth']",
#  'DIZZINESS (Light Headedness), EYE PAIN (Pain was over back of his eye sockets to around the temples and the top of his head) and HEADACHE (Mild headaches)',
#  "['Decreased appetite', 'Depression', 'Dysgeusia', 'Fatigue', 'Hearing disability', 'Psychotic disorder', 'Illusion']",
#  'Chest pain, Chills, Diarrhea',
#  "['Rash', 'Vaccination site erythema', 'Vaccination site pain', 'Vaccination site pruritus', 'Vaccination site warmth']",
#  'Illness, Lymphadenopathy, Pyrexia',
#  "['Eye swelling', 'Headache', 'Mouth swelling', 'Pharyngeal swelling', 'Productive cough', 'Secretion discharge', 'Throat clearing']",
#  "['Chills', 'Fatigue', 'Headache', 'Pain']",
#  "['Arthralgia', 'Arthritis', 'Chondropathy', 'Gait disturbance', 'Inflammation', 'Injection site pain', 'Injection site swelling']",
#  "['Chills', 'Eye irritation', 'Headache', 'Pain', 'Pyrexia']",
#  'COVID-19, Polymerase chain reaction',
#  'Blood pressure increased, Cough, Dizziness, Dyspnoea, Headache',
#  "['Dizziness', 'Nausea']",
#  'Tremor, Chills',
#  'HEART RATE INCREASED (fast heartbeat), DIZZINESS (dizziness), ASTHENIA (weakness), MYALGIA (soreness in arm) and PYREXIA (fever)',
#  'Back pain, Musculoskeletal pain, Myalgia, Pelvic pain, Pyrexia, Vaccination site paraesthesia',
#  "['Mobility decreased', 'Pain', 'Pain in extremity', 'Vaccination site pain']",
#  'Lip swelling, whole face swelled up',
#  "['Chills', 'Headache', 'Injection site pain', 'Pain', 'Pyrexia']",
#  'COVID-19, FATIGUE',
#  "['Injection site nerve damage', 'Injection site pain', 'Joint range of motion decreased']",
#  'Arthralgia, Electromyogram normal, Hypoaesthesia, Pain in extremity, Ultrasound Doppler normal',
#  "['Pain in extremity', 'Vaccination site inflammation', 'Vaccination site rash']",
#  'Computerised tomogram normal, Dizziness, Migraine',
#  "['Erythema', 'Pruritus', 'Skin warm']",
#  "['Rash erythematous', 'Rash pruritic', 'Vaccination site pain']",
#  "['Hypoaesthesia', 'Pharyngeal swelling']",
#  "['Chills', 'Condition aggravated', 'Fatigue', 'Headache', 'Injection site erythema', 'Injection site induration', 'Injection site warmth']",
#  'Burning sensation, Discomfort',
#  "['Erythema', 'Inflammation', 'Pruritus', 'Urticaria']",
#  "['Fever', 'Chills', 'Influenza like illness', 'Liver function test abnormal', 'Pyrexia', 'Rash', 'Rash erythematous']",
#  'Musculoskeletal stiffness, Vaccination site pruritus, Vaccination site swelling',
#  "['Blood lactic acid increased', 'COVID-19', 'Dyspnoea']",
#  "['Chills', 'Disorientation', 'Feeling hot', 'Musculoskeletal stiffness', 'Skin warm']",
#  'Dizziness, Hypertension, Malaise',
#  'IMMUNISATION REACTION (I had some pretty severe side effects for my second Moderna booster shot.), DIARRHOEA (diarrhea), NAUSEA (nausea), VOMITING (vomiting) and CHILLS (horrible chills that lasted all night long)',
#  "['Pruritus', 'Tenderness', 'Vaccination site erythema', 'Vaccination site warmth']",
#  '[Condition aggravated, Dizziness, Vaccination site erythema, Vaccination site induration, Vaccination site rash]',
#  '[Injection site rash, Rash]',
#  'Dysgeusia, Gastrooesophageal reflux disease, Throat irritation',
#  'Dizziness, Vertigo',
#  "['Dizziness', 'Fatigue', 'Nausea']",
#  "['Dysphagia', 'Paraesthesia', 'Paraesthesia oral', 'Pharyngeal swelling']",
#  'Asthenia, Atrial fibrillation, COVID-19, Chest X-ray abnormal, Constipation, Cough, Death, Dyspnoea, Dyspnea exertional, Fatigue, Pneumonia, Positive airway pressure therapy, Renal failure, SARS-CoV-2 test positive',
#  'Erythema, Feeling hot, Flushing',
#  "['Injection site erythema', 'Injection site swelling', 'Injection site warmth']",
#  'Arthralgia, Injected limb mobility decreased',
#  'FEELING ABNORMAL (looked like something bit him), PRURITUS (neck is itchy), RASH (front right elbow has a rash, he has been breaking out in other spot) and VACCINATION SITE RASH (Rash on vaccination site left arm, 48 hours after 2nd shot)',
#  'Fatigue, Oropharyngeal pain',
#  "['Fatigue', 'Headache', 'Injection site erythema', 'Injection site induration', 'Injection site pain', 'Injection site swelling']",
#  "['Chills', 'Nausea', 'Pain', 'Pain in extremity']",
#  "['Dizziness', 'Tachycardia']",
#  "['Erythema', 'Induration', 'Pain', 'Pruritus']",
#  "['Chills', 'Diarrhoea', 'Headache', 'Migraine', 'Muscle spasms', 'Oropharyngeal pain', 'Pain', 'Pharyngeal swelling']",
#  '[Arthralgia, Neck pain, Vaccination site pain]',
#  "['Injection site erythema', 'Injection site pain', 'Injection site swelling', 'Injection site warmth']",
#  "['Fatigue', 'Lip swelling', 'Syncope', 'Vomiting']",
#  'Pruritus, Rash',
#  'VISION BLURRED (Blurry vision), RASH (Rash below the vaccination site) and HEADACHE (Headache)',
#  "['Anxiety', 'Condition aggravated', 'Disturbance in attention', 'Feeling abnormal', 'Impaired driving ability', 'Impaired work ability']",
#  'SWELLING (Swelling under my arm after my vaccine) and MYALGIA (pain under my arm after my vaccine)',
#  "['Pruritus', 'Rash', 'Swelling face']",
#  'DERMATITIS (my dermatologist diagnosed me with a form of dermatitis) PRURITUS (triamcinolone for itching)',
#  "['Asthenia', 'Dizziness', 'Malaise', 'Pain in extremity', 'Vaccination site warmth']",
#  'Hyperhidrosis, Fatigue, Feeling abnormal, Heart rate',
#  "['Asthenia', 'Blood glucose increased', 'Diarrhoea', 'Dizziness', 'Gastrooesophageal reflux disease', 'Hypersomnia', 'Hypertension', 'Migraine', 'Nausea', 'Oxygen saturation decreased']",
#  'Itchy/Scratchy tongue and lips within 10 minutes of vaccine. Symptoms lasted for about 2-3 hours. Developed rash on RLE that was itchy, red, and bumpy around 6 hours after receiving the injection. Those symptoms lasted for about 2 hours. Breastfeeding baby developed cold symptoms (sneezing, coughing, runny nose) about 4-5 days after mom received vaccine. Symptoms are still ongoing as of day 7 after receiving vaccine.',
#  "['Asthenia', 'Chills', 'Dizziness', 'Fatigue', 'Pruritus', 'Rash']",
#  "['Dyspepsia', 'Fatigue', 'Headache', 'Impaired work ability', 'Injection site erythema', 'Injection site pruritus', 'Injection site swelling']",
#  "['Abdominal pain', 'Asthenia', 'Dehydration', 'Diarrhoea', 'Pain', 'Vomiting']",
#  "Breast enlargement two days after taking the shot, the patient's boobs grew a lot VAGINAL HAEMORRHAGE vaginal bleeding from the uterus/started bleeding and that was not a good thing VULVOVAGINAL MYCOTIC INFECTION vaginal yeast infections were still there ( re-occurring every 3-4 weeks)",
#  'Dizziness, Gait disturbance, Vertigo, Vomiting',
#  "['Feeling abnormal', 'Hyperhidrosis', 'Injection site pain', 'Migraine', 'Rash', 'Rash macular']",
#  "['Arthralgia', 'Feeling hot', 'Heavy menstrual bleeding', 'Mobility decreased']",
#  'Anxiety, Blood pressure increased, Cough, Crying, Dyspnoea, Wheezing',
#  'DIZZINESS (Dizziness), HEADACHE (Light headache) and HEAD DISCOMFORT (Pressure on the back of the head)',
#  "['Asthma', 'Bronchitis', 'Chest discomfort', 'Condition aggravated', 'Cough', 'Fatigue']",
#  "['Cold sweat', 'Loss of consciousness', 'Posture abnormal', 'Respiration abnormal']",
#  "['Anxiety', 'Feeling abnormal', 'Heart rate increased', 'Hypertension', 'Malaise']",
#  "['Injection site erythema', 'Injection site mass', 'Injection site warmth']",
#  "['Allodynia', 'Depressed mood', 'Fatigue', 'Injection site erythema', 'Injection site pain', 'Injection site rash', 'Injection site swelling', 'Lymphadenopathy']",
#  'Fluid retention, Peripheral swelling, Tenderness',
#  "['Injection site erythema', 'Injection site pruritus', 'Injection site swelling']",
#  "['Abdominal pain', 'Chills', 'Dizziness', 'Feeling hot', 'Injection site haemorrhage', 'Injection site pain']",
#  "['Abdominal pain upper', 'Back pain', 'Musculoskeletal chest pain', 'Painful respiration', 'Sleep disorder']",
#  'Affective disorder, Arthralgia, Fatigue',
#  'Fatigue, Pain, Pain in extremity, SARS-CoV-2 test positive',
#  "['Fatigue', 'Headache', 'Influenza like illness', 'Pain in extremity']",
#  "['Chills', 'Headache', 'Lethargy']",
#  'PAIN IN EXTREMITY (sore right injection site arm) FATIGUE (fatigue)',
#  'Hot flush, Night sweats',
#  "['Diarrhoea', 'Rash', 'Rash erythematous', 'Rash pruritic']",
#  'Arthralgia, Babesiosis, Borrelia test negative, C-reactive protein increased, Coinfection, Eye pain, Immunisation reaction, Inflammation, Lyme disease',
#  "['Dizziness', 'Loss of consciousness', 'Presyncope']",
#  "['Bacterial infection', 'COVID-19', 'Feeling cold', 'Nasal congestion']",
#  'Acute respiratory failure, COVID-19, COVID-19 pneumonia, Death, Dyspnoea, Endotracheal intubation, General physical health deterioration, Haemofiltration, Hypoxia, Intensive care, Leukocytosis, Positive airway pressure therapy, Renal failure, Shock',
#  "['Blood potassium decreased', 'Chest discomfort', 'Dizziness', 'Dyspnoea']",
#  "['Dizziness', 'Feeling abnormal', 'Vaccination site induration', 'Vaccination site pain', 'Vaccination site swelling']",
#  'PAIN, INFLUENZA LIKE ILLNESS',
#  'Dizziness, Hyperhidrosis, Pallor',
#  "['COVID-19', 'Dizziness', 'Dry mouth', 'Myalgia', 'Pyrexia', 'Rash']",
#  "['COVID-19', 'Oropharyngeal pain', 'Pyrexia', 'Respiratory tract congestion', 'SARS-CoV-2 test positive']",
#  "['Acute respiratory failure', 'COVID-19', 'Death', 'Sepsis', 'Unresponsive to stimuli']",
#  "['Asthenia', 'Chills', 'Dizziness', 'Hyperhidrosis', 'Hypoacusis', 'Nausea']",
#  'Nasopharyngitis, Vaccination site mass, Vaccination site pruritus, Vaccination site reaction',
#  "['Asthenia', 'Feeling abnormal', 'Feeling hot', 'Headache', 'Neck pain', 'Pain in extremity']",
#  "['Back pain', 'Injection site pruritus', 'Injection site rash', 'Pelvic pain']",
#  '[Alanine aminotransferase increased, Aspartate aminotransferase increased, Dizziness, Hepatic steatosis]',
#  "['COVID-19', 'Dyspnoea', 'Oropharyngeal pain']",
#  "['Injection site erythema', 'Injection site swelling', 'Injection site warmth']",
#  'Headache, Fatigue, Chills',
#  "['Pyrexia', 'Vaccination site pain']",
#  "['Cough', 'Dyspnoea', 'Headache', 'Injection site pain', 'Nasal congestion']",
#  'Chills, Pyrexia',
#  "['Illness', 'Pyrexia']",
#  "['Acute kidney injury', 'COVID-19', 'COVID-19 pneumonia', 'Death', 'Intensive care', 'Mental status changes', 'Respiratory failure']",
#  "['Fatigue', 'Chills', 'Pyrexia']",
#  "['Body temperature increased', 'Nausea', 'Pain', 'Rash pruritic']",
#  'Anxiety, Palpitations',
#  '[Anaphylactic reaction, Dizziness, Dyspnoea]',
#  'Arthralgia, Deep vein thrombosis, Foot fracture, Joint swelling',
#  'Chromatouria, Diarrhoea',
#  'Muscle spasms, Myalgia, Vaccination site pain',
#  "['Abdominal pain', 'Diarrhea', 'Headache', 'Myalgia', 'Nausea', 'Pyrexia', 'Vomiting']",
#  "['Dysmenorrhoea', 'Fatigue', 'Impaired work ability', 'Injection site pain', 'Menstruation irregular']",
#  "['Erythema', 'Immediate post-injection reaction', 'Loss of consciousness', 'Tremor', 'Vomiting']",
#  "['Erythema', 'Infection', 'Pain in extremity', 'Vaccination complication']",
#  "['Anxiety', 'Cardiac flutter', 'Dyspnoea', 'Fatigue', 'Headache', 'Pain in extremity']",
#  'Fatigue, Lymphadenopathy, Nausea',
#  "['Anxiety', 'Headache', 'Nervousness']",
#  "['Body temperature increased', 'Chills', 'Headache', 'Hypersomnia', 'Injection site erythema', 'Injection site pain', 'Injection site swelling']",
#  'Diarrhea, abdominal pain upper',
#  "['COVID-19', 'Cough', 'Pyrexia', 'SARS-CoV-2 test positive']",
#  'Vision in her right eye became blurry, "greyed out" and she saw "bolts of color."/Film over rt eye Vision in her right eye became blurry, "greyed out" and she saw "bolts of color. Flashes of color/shapes]',
#  "['COVID-19', 'Chills', 'Feeling cold', 'Nasal congestion', 'Pyrexia', 'SARS-CoV-2 test positive']",
#  'Arthralgia, Blood glucose increased, Condition aggravated, Musculoskeletal pain',
#  "['Abdominal discomfort', 'Arthralgia', 'Dehydration', 'Headache', 'Myalgia', 'Pyrexia', 'Vomiting']",
#  'VACCINATION SITE PAIN (arm was sore) On 04-Feb-2021, the patient experienced first dose of mRNA-1273 (Moderna COVID-19 Vaccine) (unknown route) 1 dosage form. On 04-Feb-2021, the patient experienced AXILLARY PAIN (my arm was sore underneath). At the time of the report, VACCINATION SITE PAIN (arm was sore) and AXILLARY PAIN (my arm was sore underneath) outcome was unknown. The action taken with mRNA-12',
#  "['Dizziness', 'Fall', 'Headache', 'Nausea', 'Pain', 'Tinnitus']",
#  'Asthenia, COVID-19, Chills, Constipation, Diarrhoea, Dizziness, Ear pain, Fatigue, Flatulence, Headache, Muscle spasms, Musculoskeletal stiffness, Nausea, Pain, Pain in extremity, Photophobia',
#  "['Erythema', 'Injection site pain', 'Injection site swelling']",
#  "['Dyspnoea', 'Hypoaesthesia', 'Paraesthesia oral', 'Swollen tongue']",
#  'Dyspepsia, Mechanical urticaria, Pruritus, Temperature intolerance, Urticaria',
#  'TREMOR (shaking), SOMNOLENCE (sleepy), CHILLS (Chills), PYREXIA (fever 100 degree) and VOMITING (vomit)',
#  "['Diplopia', 'Dizziness', 'Fatigue', 'Feeling jittery', 'Vision blurred']",
#  'COVID-19, SARS-CoV-2 test positive',
#  "['Asthenia', 'Headache', 'Nausea', 'Pain']",
#  'Complement factor decreased, Computerised tomogram, Headache, Magnetic resonance imaging, Sinus disorder',
#  "['COVID-19', 'Chills', 'Impaired work ability', 'Insomnia', 'Nausea', 'Pain', 'Pertussis', 'Pyrexia']",
#  "['Chills', 'Dizziness', 'Erythema', 'Flushing', 'Gait disturbance', 'Heart rate increased', 'Injection site pain', 'Ocular discomfort']",
#  "['Acute kidney injury', 'COVID-19', 'Death', 'Diverticulitis', 'Dyspnoea', 'Encephalopathy', 'Malaise', 'Metabolic acidosis', 'Pancytopenia', 'SARS-CoV-2 test positive']",
#  "['Confusional state', 'Decreased appetite', 'Feeling abnormal']",
#  'Arthralgia, Computerised tomogram head, Fatigue, Headache',
#  "['Dyshidrotic eczema', 'Pruritus', 'Rash']",
#  "['Ear discomfort', 'Fatigue', 'Headache', 'Hypertension', 'Nasal congestion', 'Vaccination site pain']",
#  "['Chills', 'Ear pain', 'Fatigue', 'Headache', 'Pharyngeal swelling']",
#  'Developed covid July 25th; tested positive for Covid-19 after 2nd dose of vaccine; On 25-Jul-2021, the patient experienced COVID-19 (Developed covid July 25th) and DRUG INEFFECTIVE (tested positive for Covid-19 after 2nd dose of vaccine) in an 87-year-old male patient who received mRNA-1273 (Moderna COVID-19 Vaccine) (batch nos. 039K20A and 013L20A) for COVID-19 vaccination.',
#  "['Chills', 'Hyperhidrosis', 'Illness', 'Nausea', 'Pyrexia']",
#  "['Eye pain', 'Headache', 'Hyperventilation', 'Pain', 'Pruritus']",
#  "['Mobility decreased', 'Pain']",
#  'Heavy menstrual bleeding, Menstruation irregular, Oligomenorrhoea',
#  'Arthralgia',
#  'Acute respiratory failure, Blood culture positive, COVID-19, Cough, Diarrhoea, Dyspnoea, Escherichia test positive, Hypoxia, Pyrexia, SARS-CoV-2 test positive, Sepsis, Staphylococcus test positive, Tachycardia, Tachypnoea',
#  'Body temperature, Headaches, Myalgia, Nasopharyngitis, Neck pain, Pyrexia',
#  "['Chest discomfort', 'Dizziness', 'Nausea', 'Rash erythematous']",
#  'Diabetes mellitus inadequate control, Glycosylated haemoglobin',
#  "['Diet refusal', 'Lethargy', 'Malaise']",
#  'Fatigue, Headache, INFLUENZA LIKE ILLNESS, Myalgia, Pyrexia',
#  'Carpal tunnel syndrome, Joint swelling, Laboratory test abnormal, Surgery, Visual impairment',
#  '[Pyrexia, Vaccination site erythema, Vaccination site pruritus, Vaccination site warmth]',
#  'Dysarthria, Facial paralysis, Feeling abnormal',
#  "['Injection site paraesthesia', 'Injection site swelling', 'Pain in extremity', 'Paraesthesia oral']",
#  'Cough, Fatigue, Headache, Pyrexia',
#  'Order the symptoms in ascending order: COVID-19 INFECTION; REVACCINATION WITH DIFFERENT COVID-19 VACCINE; CONFIRMED CLINICAL VACCINATION FAILURE; CONFIRMED COVID-19 INFECTION;',
#  '[VACCINATION SITE WARMTH (Warmness at the injection site), VACCINATION SITE INDURATION (Hardness at the injection site), VACCINATION SITE SWELLING (Swelling at the injection site) and VACCINATION SITE ERYTHEMA (Redness at the injection site)]',
#  "['Rash maculo-papular', 'Rash pruritic']",
#  "['Injection site erythema', 'Injection site rash']",
#  'Cough, Fatigue',
#  "['Pain in extremity', 'Peripheral swelling', 'Rash']",
#  'EXPOSURE TO SARS-COV-2, DIZZINESS, RASH, NAUSEA',
#  'Chills, Myalgia, Paraesthesia',
#  "['Injection site rash', 'Rash erythematous']",
#  "['Confusional state', 'Hyperhidrosis', 'Hyporesponsive to stimuli', 'Lip swelling', 'Swollen tongue']",
#  "['Body temperature increased', 'Chills', 'Fatigue', 'Influenza like illness', 'Nausea', 'Pyrexia']",
#  'This spontaneous case was reported by a consumer and describes the occurrence of VACCINATION SITE PAIN (sore below the injection site), VACCINATION SITE SWELLING (swelling below the injection site, like expanded area, kinda firm and elevated), VACCINATION SITE PRURITUS (itching on the site, really intense like a mosquito bite) and VACCINATION SITE ERYTHEMA (the firm area is now red) in a 46-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccin',
#  "MUSCULOSKELETAL STIFFNESS (Stiff neck on opposite side from injected arm/Pers. neck pain opp side), PAIN (made pain worse), INSOMNIA (Sleeping is painful), GAIT DISTURBANCE (Walking is painful) and VACCINATION SITE PAIN (I felt a slight sort of twinge/fluttering from the shot location across my back/ neck but it didn't hurt at the time)",
#  "['Chills', 'Erythema', 'Headache', 'Influenza like illness', 'Injection site erythema', 'Injection site nodule']",
#  "['Arthralgia', 'Body temperature increased', 'Chills', 'Delirium', 'Headache', 'Injection site pain', 'Injection site warmth']",
#  "['Headache', 'Fatigue', 'Injection site joint pain']",
#  "['Asthenia', 'Diarrhoea', 'Muscular weakness', 'Nausea', 'Peripheral swelling', 'Urticaria']",
#  "['Vomiting', 'Heart rate decreased']",
#  'Condition aggravated',
#  "['Diarrhoea', 'Influenza like illness', 'Pyrexia']",
#  "['Abdominal pain', 'Arthralgia', 'Injection site erythema', 'Injection site pain', 'Injection site swelling', 'Lymph node pain', 'Lymphadenopathy']",
#  "['Hypertension', 'Nausea', 'Panic attack']",
#  "['Chills', 'Feeling abnormal', 'Headache', 'Illness', 'Pain', 'Vaccination site pain']",
#  '[Headache, Heart rate increased, Injection site pruritus, Palpitations]',
#  'Arthralgia, Gait inability, Pain in extremity, Red blood cell sedimentation rate increased',
#  'Myalgia, Pyrexia',
#  "['Chills', 'Dizziness', 'Headache', 'Nausea', 'Nightmare', 'Pain', 'Vertigo']",
#  "['Back pain', 'Dysphoria', 'Dyspnoea', 'Pain', 'Wheezing']",
#  'Head discomfort',
#  '[Vaccination site haemorrhage, vaccination site pain]',
#  'Injection site pain, Rash, Vaccination site erythema',
#  "['Computerised tomogram normal', 'Contusion', 'Full blood count', 'Headache', 'Injection site erythema', 'Pain', 'Platelet count decreased', 'Stomatitis']",
#  'Feeling abnormal, Myalgia, Pulse abnormal, Spinal pain',
#  'RASH (Rash on her breast around nipple) and VACCINATION SITE RASH (Rash at the injection/Two rash near injection site)',
#  'Asthenia, COVID-19, Condition aggravated, Decreased appetite, Urinary tract infection',
#  "['Chills', 'Dyspnoea', 'Feeling abnormal']",
#  "['Dizziness', 'Impaired work ability', 'Pain']",
#  'Asthenia, Blood pressure increased, Blood test abnormal, Cardiovascular symptom, Computerised tomogram normal, Dystasia, Electrocardiogram normal, Magnetic resonance imaging spinal abnormal, Mobility decreased, Muscular weakness, Myelin oligodendrocyte glycoprotein antibody-associated disease, Myelitis transverse, Spinal disorder',
#  'Back pain, Body temperature increased, Bone pain, Chills, Diarrhoea, Epistaxis, Flushing, Headache, Impaired work ability, Nasal congestion, Nasal dryness, Nausea, Pain, Rhinorrhoea',
#  'ARTHRALGIA (pain in the joints), HEADACHE (Severe headache), CHILLS (Chills) and PYREXIA (Fever of 39°C that did not drop down after taking several Tylenol)',
#  "['Akinesia', 'Aphasia', 'Asthenia', 'Dysarthria', 'Dyspnoea exertional', 'Fatigue', 'Feeling abnormal', 'Loss of personal independence in daily activities', 'Mobility decreased', 'Myocarditis', 'Pneumonia']",
#  'Discomfort, Axillary mass, Pain',
#  "['COVID-19', 'Fatigue', 'Respiratory tract congestion', 'SARS-CoV-2 test positive']",
#  "ASTHENIA (weakness), INFLUENZA LIKE ILLNESS (flu like symptoms), ILLNESS (sick) and MOBILITY DECREASED (couldn't move)",
#  "['Chills', 'Erythema', 'Headache', 'Pain', 'Swelling', 'Swelling face']",
#  "['Dysstasia', 'Hot flush', 'Hyperhidrosis', 'Malaise', 'Nausea', 'Presyncope']",
#  "['COVID-19', 'Chills', 'Oropharyngeal pain', 'Pain', 'SARS-CoV-2 test positive']",
#  'Dysphagia, Feeling abnormal, Heart rate increased, Pharyngeal swelling, Throat irritation, Throat tightness',
#  "['Injection site pain', 'Injection site rash', 'Petechiae', 'Rash']",
#  "['Inflammation', 'Pain', 'Pain in extremity', 'Peripheral swelling']",
#  "['Arthralgia', 'Erythema', 'Mobility decreased', 'Pain in extremity']",
#  'Arthralgia, Computerised tomogram normal, Fatigue, Gait disturbance, Headache, Impaired work ability, Pain',
#  "['Pain in extremity', 'Pruritus', 'Rash morbilliform']",
#  "['Chills', 'Feeling cold', 'Headache', 'Malaise', 'Mobility decreased', 'Pain', 'Pain in extremity', 'Pyrexia']",
#  "['Arthralgia', 'Back pain', 'Chills', 'Dyspnoea', 'Fatigue', 'Headache', 'Heart rate decreased', 'Injection site erythema', 'Injection site pruritus', 'Nausea']",
#  "['Electrocardiogram', 'Heart rate increased', 'Herpes zoster', 'Palpitations']",
#  'Body temperature, Myalgia, Pyrexia',
#  "['Dizziness', 'Feeling hot', 'Loss of consciousness']",
#  'Blister, Erythema, Kidney infection, Nausea, Pyrexia',
#  'Erythema, Feeling abnormal, Injection site swelling, Peripheral swelling, Respiratory tract congestion',
#  "['Pain of skin', 'Rash erythematous', 'Rash papular', 'Skin burning sensation', 'Skin exfoliation']",
#  'Colitis microscopic, Colonoscopy abnormal, Diarrhoea, Vaccination complication',
#  "['Adverse drug reaction', 'Death']",
#  'Asthenia, Nausea, Pyrexia',
#  "['Alopecia', 'Asthenia', 'Joint swelling', 'Thyroid disorder', 'Vision blurred']",
#  'Fatigue, Injection site bruising, Erythema, Pain in extremity',
#  "['COVID-19', 'Chills', 'Headache', 'Nausea', 'Pyrexia', 'Vomiting']",
#  'Endocrine ophthalmopathy Thyroid function test',
#  "['Dizziness', 'Feeling hot', 'Heart rate increased', 'Mobility decreased', 'Musculoskeletal discomfort', 'Neuralgia', 'Vaccination site pain']",
#  'Asthenia, Dizziness, Diarrhea',
#  "['Chills', 'Diarrhoea', 'Fatigue', 'Injection site erythema', 'Injection site induration', 'Injection site swelling']",
#  'Body temperature, Fatigue, Pyrexia',
#  '[Fatigue, Pain, Vaccination site pain]',
#  'Order the symptoms in ascending order: IMMUNODEFICIENCY (Immunocompromised/LIMITED ANTIBODY RESPONSE TO JANSSEN COVID-19 VACCINE AND MODERNA COVID-19 VACCINE) (seriousness criterion medically significant), DIARRHOEA (Diarrhea), INTERCHANGE OF VACCINE PRODUCTS (interchange of vaccine products) and COVID-19 IMMUNISATION (revaccination with different COVID-19 vaccine)',
#  "['Dizziness', 'Dyspnoea', 'Panic attack']",
#  'Chest pain, Feeling abnormal, Heart rate abnormal, Heart rate increased, Impaired work ability, Nausea',
#  '[Fatigue, Headache, Muscle tightness, Nausea]',
#  'PAIN IN EXTREMITY (sore arm), PYREXIA (High fever), CHILLS (chills), HEADACHE (headache) and MYALGIA (body ache)',
#  'Fatigue, Vaccination site pain',
#  "['Chills', 'Cough', 'Discomfort', 'Fatigue', 'Feeling abnormal', 'Headache', 'Pain', 'Pain in extremity']",
#  "['Bundle branch block right', 'Cardiovascular evaluation', 'Chest discomfort', 'Dyspnoea', 'Mobility decreased', 'Muscular weakness']",
#  "['Balance disorder', 'Dizziness', 'Retching', 'Sensation of foreign body', 'Vertigo']",
#  "['Diarrhoea', 'Fatigue', 'Headache', 'Injection site pain', 'Lethargy']",
#  "['Injected limb mobility decreased', 'Throbbing severe pain in right deltoid area of arm where vaccine was placed', 'Throbbing severe pain in right deltoid area of arm where vaccine was placed', 'Throbbing severe pain in right deltoid area of arm where vaccine was placed', 'Throbbing severe pain in right deltoid area of arm where vaccine was placed', 'Throbbing severe pain in right deltoid area of arm where vaccine was placed']",
#  "['Injection site erythema', 'Injection site pruritus', 'Injection site swelling']",
#  'Swelling, Tachycardia, Urticaria',
#  "['Injection site erythema', 'Injection site pruritus', 'Injection site swelling', 'Rash']",
#  "['Cough', 'Oropharyngeal pain', 'Rhinitis allergic', 'Throat irritation']",
#  "['Cough', 'Headache', 'Pain', 'Pyrexia', 'Sinus congestion', 'Vaccination site pain', 'Vaccination site swelling']",
#  'PAIN (A little bit of aching), OROPHARYNGEAL PAIN (Sore throat) and HEADACHE (Headache)',
#  "['Biopsy', 'Chest X-ray abnormal', 'Recurrent cancer']",
#  'Asthenia, Decreased appetite, Defaecation disorder, Eye pain, Fatigue, Headache, Injection site erythema, Insomnia, Pain, Pain in extremity, Urine output decreased',
#  'Ageusia, Electrocardiogram, Gait disturbance, Heart rate increased, Muscular weakness',
#  "['Chills', 'Headache', 'Muscle spasms', 'Myalgia', 'Skin mass']",
#  "['Arthralgia', 'Chills', 'Diarrhoea', 'Fatigue', 'Headache', 'Myalgia', 'Nausea']",
#  'Dehydration, Headache, Fever, Chills, Myalgia',
#  "['Headache', 'Platelet count decreased', 'Respiratory disorder']",
#  "['Dizziness', 'Loss of consciousness', 'Nausea']",
#  "['Anaemia', 'Bradycardia', 'Diarrhea', 'Dizziness', 'Dyspnoea', 'Fatigue', 'Headache', 'Nausea', 'Palpitations', 'Platelet count decreased', 'Syncope', 'Thrombocytopenia', 'Vomiting']",
#  "['Chest discomfort', 'Dizziness', 'Dyspnoea', 'Immediate post-injection reaction', 'Palpitations', 'Throat tightness']",
#  '[Arthralgia, Injected limb mobility decreased, Injection site pain, Muscular weakness]',
#  'Arthralgia, COVID-19, Cough, Fatigue, Fluid retention, Pyrexia, Respiratory tract congestion, SARS-CoV-2 test positive, Sneezing',
#  'Blister, Rash',
#  "['Chest discomfort', 'Dizziness', 'Headache', 'Fine motor skill dysfunction', 'Headache', 'Visual impairment']",
#  'Dry mouth, Dysphagia, Throat irritation',
#  "['Pain in extremity', 'Tinnitus', 'Vaccination site pain']",
#  'PAIN IN EXTREMITY (Arm pain), PYREXIA (Fever), COUGH (Cough), HEADACHE (Headache), SNEEZING (Sneezing), FATIGUE (Fatigue), NASAL CONGESTION (Congestion)',
#  '[Mass, Progressive facial hemiatrophy, Swelling face]',
#  "['Erythema', 'Halo vision', 'Headache', 'Lymphadenopathy', 'Nausea', 'Pain', 'Pain in extremity']",
#  "['Ageusia', 'Back pain', 'Pain', 'Pain in extremity']",
#  "['Epistaxis', 'Headache', 'Nasal congestion', 'Pain']",
#  '[Fatigue, Injection site pain, Oropharyngeal pain, Pain]',
#  'Fatigue, Headache, Injection site pain, Pain',
#  'Agitation, Confusional state, Loss of personal independence in daily activities',
#  'PRURITUS (I got itchy arm) On 13-Feb-2021, the patient experienced PRURITUS (I got itchy arm) On 14-Feb-2021, the patient experienced INJECTION SITE ERYTHEMA',
#  'Back pain, Fall, Gait disturbance, Urinary tract infection, Wheelchair user',
#  "['Dizziness', 'Loss of consciousness', 'Syncope']",
#  "['Gastrointestinal disorder', 'Gastrointestinal haemorrhage', 'Gastrointestinal mucosa hyperaemia', 'Intestinal ulcer', 'Oedema mucosal']",
#  "['Dizziness', 'Feeling hot']",
#  "['Anxiety', 'Chills', 'Fatigue', 'Influenza like illness', 'Insomnia', 'Pain', 'Palpitations']",
#  "['Death', 'Dyspnoea', 'Respiratory distress', 'Use of accessory respiratory muscles', 'Wheezing']",
#  "['Erythema', 'Pain of skin', 'Pruritus', 'Sensitive skin', 'Skin discolouration']",
#  "['Cough', 'Injection site pain', 'Injection site swelling', 'Malaise', 'Pain in extremity']",
#  "['Injection site erythema', 'Injection site pain', 'Injection site warmth']",
#  "['Loss of consciousness', 'Pallor', 'Tremor']",
#  "['Dizziness', 'Muscular weakness', 'Paraesthesia']",
#  'Chills, Lymphadenopathy, Myalgia, Pyrexia, Vaccination site erythema',
#  "FEELING HOT (Lump in her armpit (injection side), it's about 2 inches large and hot) Lymphadenopathy (Lump in her armpit (injection side), it's about 2 inches large and hot)",
#  "['Chills', 'Dizziness', 'Fatigue', 'Heart rate', 'Influenza like illness', 'Walking aid user']",
#  'Eye swelling, Eye pain, Nausea',
#  "['Dizziness', 'Feeling drunk', 'Injected limb mobility decreased', 'Injection site pain', 'Vertigo']",
#  "['Chills', 'Computerised tomogram', 'Hypoaesthesia', 'Hypoaesthesia oral', 'Pain', 'Pyrexia']",
#  "['Immediate post-injection reaction', 'Injection site pain', 'Pain in extremity', 'Paralysis']",
#  "['Maternal exposure during breast feeding', 'Vaccination site pain']",
#  "['Erythema', 'Hypersensitivity', 'Injection site pain', 'Peripheral swelling', 'Pruritus']",
#  "['Loss of consciousness', 'Tremor']",
#  'Cough, Rhinorrhoea, Throat irritation',
#  'PAIN IN EXTREMITY (feels her arm sore), MYALGIA (body aches) and HEADACHE (feels her arm sore, had a low grade headache and body aches)',
#  'Allergy to vaccine, Chills, Fatigue',
#  "['Amenorrhoea', 'Condition aggravated']",
#  'Sneezing, RHINORRHOEA, COUGH',
#  'Arthralgia, Dizziness, Fall',
#  'Fatigue, Urticaria',
#  '[VACCINATION SITE ERYTHEMA (huge red bump that came up on her arm) and VACCINATION SITE SWELLING (huge red bump that came up on her arm)]',
#  "['Abdominal discomfort', 'Asthenia', 'Illness', 'Muscle discomfort', 'Nausea', 'Pain in extremity']",
#  "['Gingival discolouration', 'Hyperaesthesia teeth', 'Pyrexia']",
#  "['Blister rupture', 'Peripheral swelling', 'Pruritus', 'Rash']",
#  "['COVID-19', 'Dyspnoea', 'Oxygen saturation decreased', 'Positive airway pressure therapy', 'Respiratory failure']",
#  "['Abdominal pain upper', 'Back pain', 'Chills', 'Decreased appetite', 'Depressed mood', 'Fatigue', 'Head discomfort', 'Headache', 'Injected limb mobility decreased', 'Muscle spasms', 'Nausea', 'Pain', 'Pain in extremity']",
#  'Arthralgia, Mobility decreased, Pain',
#  'Lump where right ear meets his head, about where glasses would sit. Next morning woke up with golf ball sized lump. The lump removed and determined to be a tumor with blood supply and striated nerves.]',
#  'Malaise, Vaccination site erythema, Vaccination site rash',
#  "['Erythema', 'Induration', 'Vaccination site discolouration', 'Vaccination site erythema', 'Vaccination site induration', 'Vaccination site pruritus']",
#  'Malaise, Fatigue, Pyrexia, Somnolence',
#  "['Injection site erythema', 'Injection site pruritus', 'Injection site swelling', 'Injection site warmth']",
#  "['Injection site pain', 'Injection site pruritus', 'Injection site urticaria']",
#  "['Rash', 'Rash pruritic', 'Swelling face']",
#  'Back pain, Musculoskeletal stiffness, Pain in extremity',
#  'Erythema, Herpes zoster, Peripheral swelling',
#  "['Erythema', 'Skin irritation', 'Skin swelling', 'Vaccination site warmth']",
#  'ILLNESS (was sick), PRODUCT DOSE OMISSION ISSUE (Missed her second dose/More than 35 days have passed)',
#  'Fatigue, Throat irritation, Vaccination site bruising, Vaccination site mass',
#  'Lymphadenopathy, Mobility decreased, Pain in extremity',
#  "['Erythema', 'Peripheral swelling', 'Pruritus']",
#  "['Chills', 'Erythema', 'Headache', 'Injection site erythema', 'Injection site nodule', 'Injection site warmth', 'Pain in extremity']",
#  "['Arthralgia', 'Asthenia', 'Chills', 'Erythema', 'Fatigue', 'Injection site pain', 'Nausea', 'Pruritus', 'Pyrexia']",
#  'FEELING ABNORMAL ("felt really bad"), INSOMNIA ("didn\'t sleep well that evening")',
#  "['Abdominal pain', 'Arthralgia', 'Axillary pain', 'Breast pain', 'Chest pain', 'Chills', 'Grip strength decreased', 'Headache', 'Injection site pain', 'Myalgia', 'Neuralgia', 'Pain in extremity', 'Palpitations', 'Posture abnormal']",
#  'International normalised ratio, International normalised ratio decreased',
#  "['Rash papular', 'Rash pruritic', 'Urticaria']",
#  'Body temperature increased, Chills, Fatigue, Injection site pain',
#  'PAIN IN EXTREMITY (cannot lift arm without pain), VACCINATION SITE PAIN (pain in left arm where she got the shot) and ARTHRALGIA (joint/elbow hurts) On 26-Jan-2021, the patient experienced PAIN IN EXTREMITY (cannot lift arm without pain), VACCINATION SITE PAIN (pain in left arm where she got the shot) and ARTHRALGIA (joint/elbow hurts)',
#  'Abdominal discomfort, Asthenia, COVID-19, Chills, Dyspnoea, Headache, Hypersomnia, Nausea, Neck pain, Pyrexia, SARS-CoV-2 test positive',
#  "['Chest discomfort', 'Dyspnoea', 'Fatigue', 'Lip swelling']",
#  '[Vaccination site erythema, Vaccination site pruritus, Vaccination site swelling]',
#  "['Adverse reaction', 'Chest discomfort', 'Chest pain', 'Dizziness', 'Fatigue', 'Flushing', 'Hyperhidrosis', 'Hypertension', 'Lethargy', 'Nausea', 'Paraesthesia']",
#  "['Arthralgia', 'Back pain', 'Blood pressure fluctuation', 'Blood urine present', 'Computerised tomogram', 'Fatigue', 'Headache', 'Muscle tightness', 'Neck pain', 'Pain in extremity', 'Palpitations', 'Pollakiuria']",
#  'Eye irritation, Ulcerative keratitis, Visual impairment',
#  "['COVID-19', 'Complication associated with device', 'Death', 'Decreased appetite', 'Diarrhoea', 'Dyspnoea', 'Hypoxia', 'Peritonitis', 'Positive airway pressure therapy', 'Respiratory disorder']",
#  'COVID-19, Cough, Rhinorrhoea, SARS-CoV-2 test positive',
#  '[Injection site erythema, Myalgia, Vaccination site pain, Vaccination site swelling, Vaccination site warmth]',
#  "['Cough', 'Dry throat', 'Pain in extremity', 'Peripheral swelling']",
#  "['Myalgia', 'Neck pain', 'Oropharyngeal pain']",
#  "['Chest pain', 'Lymphadenopathy', 'Musculoskeletal chest pain', 'Pain in extremity']",
#  'COVID-19, FEELING HOT, FATIGUE',
#  'Headache, Fatigue, Chills, Vomiting',
#  'Body temperature, Pyrexia',
#  "['Aphasia', 'Asthenia', 'Choking', 'Dizziness', 'Dyspnoea', 'Fatigue', 'Headache', 'Myalgia', 'Pain']",
#  "['Dyspnoea', 'Injection site erythema', 'Injection site pruritus', 'Throat tightness']",
#  'HEADACHE (headache) and CHILLS (chills)',
#  'INFLUENZA LIKE ILLNESS (feels like she has the flu), ARTHRALGIA (joint pain), HEADACHE (headache), PYREXIA (fever), CHILLS (chills) and NAUSEA (feels nauseous)',
#  'Atelectasis, COVID-19, Computerised tomogram thorax abnormal, Dyspnoea, SARS-CoV-2 test positive',
#  "['Dyspnoea', 'Fatigue', 'Hyperhidrosis', 'Nausea', 'Vomiting']",
#  "['Oral herpes', 'Rash']",
#  'COVID-19, Oropharyngeal pain',
#  'RASH ERYTHEMATOUS (red rash on arm) and CHILLS (chills)',
#  "['Injection site pruritus', 'Injection site rash', 'Injection site warmth']",
#  "['Petechiae', 'Purpura']",
#  "['Erythema', 'Pruritus', 'Rash']",
#  "['Anxiety', 'Blood pressure increased', 'Cold sweat', 'Dizziness', 'Feeling hot', 'Nausea', 'Paraesthesia oral', 'Nausea', 'Tremor']",
#  "['Diarrhea', 'Headache', 'Insomnia', 'Lethargy', 'Nausea', 'Pain in extremity', 'Vaccination site pruritus', 'Vaccination site urticaria', 'Vaccination site warmth']",
#  'Back pain, Hyperacusis, Migraine, Myalgia, Pain in extremity',
#  "['Eye movement disorder', 'Vertigo', 'Vomiting']",
#  'RASH (After COVID shots hands broke out), ECZEMA (Eczema) and HYPERSENSITIVITY (Allergies)',
#  "['Dyspnoea', 'Impaired work ability', 'Influenza virus test positive', 'Joint swelling', 'Pain', 'Rheumatoid factor negative']",
#  'INSOMNIA (Was up all night), GAIT DISTURBANCE (Could hardly walk), GASTROOESOPHAGEAL REFLUX DISEASE (Acid reflux), ILLNESS (Felt very sick), HEADACHE (Headache) and MYALGIA (Body aches)',
#  'Peripheral swelling, Pruritus',
#  "['Anxiety', 'Erythema', 'Pain', 'Somnolence', 'Pain', 'Erythema', 'Fatigue', 'Vaccination site pain']",
#  "['Aphasia', 'Chest discomfort', 'Dyspnoea', 'Lip swelling', 'Peripheral swelling', 'Pruritus', 'Swelling face', 'Throat tightness']",
#  "['Asthenia', 'Chills', 'Decreased appetite', 'Injection site pain', 'Moaning', 'Pain']",
#  'Erythema, Rash on torso, Headache',
#  '[Itchy Injection Site, Sore Injection Site, Tender Injection Site]',
#  "['Fall', 'Loss of consciousness', 'Skin laceration']",
#  "['Gingival pain', 'Hypoaesthesia oral', 'Noninfective gingivitis', 'Oedema', 'Oral pain', 'Stomatitis']",
#  'Hyperhidrosis, Loss of consciousness, Presyncope',
#  "['Asthenia', 'Axillary mass', 'Disturbance in attention', 'Dizziness', 'Fatigue', 'Headache', 'Lymphadenopathy']",
#  'ILLNESS (Sick as a dog), DIARRHOEA (Diarrhea), ABDOMINAL DISCOMFORT (Stomach issues), WEIGHT DECREASED (Has lost 10 pounds), EATING DISORDER (Has not been able to eat for weeks), JOB DISSATISFACTION (Lost work days) and HEADACHE (Headaches)',
#  "['Pain in extremity', 'Peripheral swelling', 'Rash', 'Urinary tract infection']",
#  "['Inflammation', 'Injection site discolouration', 'Injection site pruritus', 'Injection site rash', 'Injection site swelling', 'Peripheral swelling', 'Rash erythematous']",
#  "['Immediate post-injection reaction', 'Injected limb mobility decreased', 'Injection site pain', 'Pain in extremity']",
#  "['Eye haemorrhage', 'Injection site pruritus', 'Injection site swelling', 'Pain in extremity']",
#  'Bone pain, Fatigue, Headache, Myalgia, Pain in extremity, Vaccination site movement impairment',
#  'Arthritis, Back pain, Condition aggravated, Joint swelling, Pain in extremity, Sleep disorder',
#  'Chills, Gait disturbance, Malaise, Nausea, Pyrexia',
#  'Order the symptoms in chronological order: had another heart attack ; had 2 heart attacks ; swollen feet ; was very fatigued with little walking ; A lot of pain in the arm of the injection ( left arm); MYOCARDIAL INFARCTION ( Had 2 heart attacks ) (seriousness criteria hospitalization and medically significant) (seriousness criteria hospitalization and medically significant) (seriousness criteria hospitalization and medically significant) (seriousness criteria hospitalization and medically significant',
#  "['Immediate post-injection reaction', 'Injection site erythema', 'Injection site pain', 'Injection site pruritus', 'Injection site swelling', 'Musculoskeletal stiffness', 'Neck pain', 'Pain', 'Pain in extremity']",
#  'Haematuria, Haemorrhage urinary tract, Thirst',
#  'Asthma, Chest discomfort, Condition aggravated, Cough, Dyspnoea, Nervousness',
#  "['Immediate post-injection reaction', 'Nasal congestion', 'Pain', 'Pain in extremity']",
#  'Chest pain, Night sweats',
#  "['Asthenia', 'Dizziness', 'Nausea']",
#  'Injection site erythema, Myalgia, Pyrexia',
#  "['Rash', 'Rash erythematous', 'Rash macular']",
#  "['Movement disorder', 'Neck pain', 'Pain in extremity']",
#  'Seizures, Fall',
#  "['Erythema', 'Injection site pain', 'Injection site pruritus']",
#  "['Dizziness', 'Dyspnoea', 'Feeling abnormal']",
#  "['Eye swelling', 'Lip swelling', 'Gingival swelling', 'Pruritus', 'Rash']",
#  'Hyperhidrosis, Presyncope, Syncope, Vomiting',
#  'Cough, Malaise, Pyrexia',
#  'ABDOMINAL PAIN UPPER (Stomach ache) and HEADACHE (Headache)',
#  "['Injection site bruising', 'Injection site erythema', 'Injection site pruritus', 'Injection site warmth']",
#  "['Rash', 'VACCINATION SITE MOVEMENT IMPAIRMENT', 'VACCINATION SITE PAIN', 'VACCINATION SITE RASH']",
#  "['Chills', 'Contusion', 'Erythema', 'Feeling abnormal', 'Headache', 'Injection site warmth', 'Pain', 'Pain in extremity']",
#  "['Headache', 'Hypertension', 'Neck pain', 'Pain', 'Tachycardia']",
#  "['Injection site mass', 'Injection site pruritus', 'Injection site warmth']",
#  'FEELING ABNORMAL (felt bad) MALAISE (Stuck in bed)',
#  "['Asthenia', 'Blood lactic acid', 'Body temperature increased', 'COVID-19', 'Dystasia', 'Gait inability', 'Oxygen saturation decreased', 'SARS-CoV-2 test positive']",
#  'Chills, INFLUENZA LIKE ILLNESS, Chills, Myalgia',
#  "['Bradycardia', 'Cardiac monitoring abnormal', 'Chest discomfort', 'Dizziness', 'Electrocardiogram abnormal', 'Heart rate decreased', 'Heart rate increased', 'Musculoskeletal discomfort', 'Tachycardia']",
#  "['Headache', 'Neuralgia', 'Pain', 'Pyrexia']",
#  "['Back pain', 'Body temperature', 'Chills', 'Headache', 'Pain in extremity', 'Pyrexia']",
#  "['Cough', 'Pain', 'Pyrexia', 'Respiratory tract congestion', 'Rhinorrhoea']",
#  "['Flushing', 'Injection site erythema', 'Injection site pruritus', 'Injection site rash']",
#  "['Vaccination site erythema', 'Vaccination site pain', 'Vaccination site pruritus', 'Vaccination site swelling']",
#  'Amnesia, Dizziness, Dyspnoea, Erythema, Hypersensitivity, Throat tightness',
#  "['Hypoaesthesia', 'Neuralgia', 'Pain in extremity']",
#  "['Injection site pain', 'Injection site rash', 'Injection site swelling']",
#  '["Dementia Alzheimer\'s type", \'Fatigue\', \'Headache\', \'Malaise\']',
#  'Lymphadenopathy, Neck pain, Pruritus, Rash, Rash macular',
#  "['Dry skin', 'Erythema']",
#  "['Abdominal pain upper', 'Back pain', 'Constipation', 'Vomiting']",
#  'Fatigue, Headache, Lymphadenopathy, Nausea, Pain in extremity, Vaccination site bruising, Vaccination site swelling',
#  "['Chills', 'Fatigue', 'Headache', 'Vaginal haemorrhage']",
#  "['Abdominal discomfort', 'Chills', 'Cough', 'Decreased appetite', 'Diarrhoea', 'Dizziness', 'Fatigue', 'Headache', 'Hyperhidrosis', 'Hypogeusia', 'Incision site pain', 'Oropharyngeal pain', 'Pain', 'Pain in extremity']",
#  "['Anxiety', 'Blood thyroid stimulating hormone normal', 'Chills', 'Dizziness', 'Fatigue', 'Impaired work ability', 'Lymphadenopathy', 'Metabolic function test normal', 'Nausea', 'Pain in extremity', 'Paraesthesia', 'Pregnancy test negative', 'Vertigo']"]

# %%
## TODO: Need to convert this to CSV
eval_df_wpeft.to_csv(os.path.join(results_dir, f'{model_name}-results.csv'), index=False)

# %% [markdown]
# ### Inference Using Flant5-Large with PEFT:

# %%
# Step 1: Load the pre-trained PEFT model
peft_model = PeftModel.from_pretrained(base_model, peft_model_path, is_trainable=False)

## Step 2: Perform batch inference using the loaded model
predicted_sequence_peft = batch_inference(peft_model, tokenizer, test_dataset['input_text'].to_list())

## Step 3: Create a DataFrame for evaluation
eval_df_peft = create_eval_df(test_dataset, predicted_sequence_peft)
eval_df_peft[['symptom_text', 'true_sequence', 'predicted_sequence']].head(10)
# Out:
# Processed Batch: 0 successfully!!
# Processed Batch: 1 successfully!!
# Processed Batch: 2 successfully!!
# Processed Batch: 3 successfully!!
# Processed Batch: 4 successfully!!
# Processed Batch: 5 successfully!!
# Processed Batch: 6 successfully!!
# Processed Batch: 7 successfully!!
# Processed Batch: 8 successfully!!
# Processed Batch: 9 successfully!!
# Processed Batch: 10 successfully!!
# Processed Batch: 11 successfully!!
# Processed Batch: 12 successfully!!
# Processed Batch: 13 successfully!!
# Processed Batch: 14 successfully!!
# Processed Batch: 15 successfully!!
# Processed Batch: 16 successfully!!
# Processed Batch: 17 successfully!!
# Processed Batch: 18 successfully!!
# Processed Batch: 19 successfully!!
# Processed Batch: 20 successfully!!
# Processed Batch: 21 successfully!!
# Processed Batch: 22 successfully!!
# Processed Batch: 23 successfully!!
# Processed Batch: 24 successfully!!
# Processed Batch: 25 successfully!!
# Processed Batch: 26 successfully!!
# Processed Batch: 27 successfully!!
# Processed Batch: 28 successfully!!
# Processed Batch: 29 successfully!!
# Processed Batch: 30 successfully!!
# Processed Batch: 31 successfully!!
# Processed Batch: 32 successfully!!
# Processed Batch: 33 successfully!!
# Processed Batch: 34 successfully!!
# Processed Batch: 35 successfully!!
# Processed Batch: 36 successfully!!
# Processed Batch: 37 successfully!!
# Processed Batch: 38 successfully!!
# Processed Batch: 39 successfully!!
# Processed Batch: 40 successfully!!
# Processed Batch: 41 successfully!!
# Processed Batch: 42 successfully!!
# Processed Batch: 43 successfully!!
# Processed Batch: 44 successfully!!
# Processed Batch: 45 successfully!!
# Processed Batch: 46 successfully!!
# Processed Batch: 47 successfully!!
# Processed Batch: 48 successfully!!
# Processed Batch: 49 successfully!!
# Processed Batch: 50 successfully!!
# Processed Batch: 51 successfully!!
# Processed Batch: 52 successfully!!
# Processed Batch: 53 successfully!!
# Processed Batch: 54 successfully!!
# Processed Batch: 55 successfully!!
# Processed Batch: 56 successfully!!
# Processed Batch: 57 successfully!!
# Processed Batch: 58 successfully!!
# Processed Batch: 59 successfully!!
# Processed Batch: 60 successfully!!
# Processed Batch: 61 successfully!!
# Processed Batch: 62 successfully!!
# Processed Batch: 63 successfully!!
# Processed Batch: 64 successfully!!
# Processed Batch: 65 successfully!!
# Processed Batch: 66 successfully!!
# Processed Batch: 67 successfully!!
# Processed Batch: 68 successfully!!
# Processed Batch: 69 successfully!!
# Processed Batch: 70 successfully!!
# Processed Batch: 71 successfully!!
# Processed Batch: 72 successfully!!
# Processed Batch: 73 successfully!!
# Processed Batch: 74 successfully!!
# Processed Batch: 75 successfully!!
# Processed Batch: 76 successfully!!
# Processed Batch: 77 successfully!!
# Processed Batch: 78 successfully!!
# Processed Batch: 79 successfully!!
# Processed Batch: 80 successfully!!
# Processed Batch: 81 successfully!!
# Processed Batch: 82 successfully!!
# Processed Batch: 83 successfully!!
# Processed Batch: 84 successfully!!
# Processed Batch: 85 successfully!!
# Processed Batch: 86 successfully!!
# Processed Batch: 87 successfully!!
# Processed Batch: 88 successfully!!
# Processed Batch: 89 successfully!!
# Processed Batch: 90 successfully!!
# Processed Batch: 91 successfully!!
# Processed Batch: 92 successfully!!
# Processed Batch: 93 successfully!!
# Processed Batch: 94 successfully!!
# Processed Batch: 95 successfully!!
# Processed Batch: 96 successfully!!
# Processed Batch: 97 successfully!!
# Processed Batch: 98 successfully!!
# Processed Batch: 99 successfully!!
#                                         symptom_text  \
# 0  A few days after my vaccine, I noticed under t...
# 1  Period schedule on and off the chart; Increase...
# 2  within 24 hours of receiving my 2nd dose, I fi...
# 3  Side effects seem to have cleared up by the 17...
# 4  I received my first Moderna vaccine on one/14/...
# 5  Patient experienced only chills; Fever; Sorene...
# 6  8 days after the first vaccine dose, I had itc...
# 7  Sore arm; Very tired; Headache; Burning sensat...
# 8  Chills; Urinating (More often); This spontaneo...
# 9  Swelling Left arm, upper Calves and legs swell...
#
#                                        true_sequence  \
# 0                                [Blister, Erythema]
# 1  [Menstrual disorder, Heavy menstrual bleeding,...
# 2  [Pyrexia, Chills, Headache, Myalgia, Neuralgia...
# 3               [Vaccination complication, Headache]
# 4  [Lymphadenopathy, Arthralgia, Pain in extremit...
# 5                         [Chills, Pyrexia, Myalgia]
# 6  [Injection site pruritus, Injection site swell...
# 7  [Burning sensation, Headache, Pain in extremit...
# 8                              [Chills, Pollakiuria]
# 9  [Peripheral swelling, Vaccination site bruisin...
#
#                                   predicted_sequence
# 0                                [Blister, Erythema]
# 1  [Menstrual disorder, Heavy menstrual bleeding,...
# 2  [Pyrexia, Chills, Myalgia, Myalgia, Neuralgia,...
# 3               [Vaccination complication, Headache]
# 4  [Carbohydrate antigen 125, Lymphadenopathy, Ly...
# 5                         [Chills, Pyrexia, Myalgia]
# 6  [Injection site swelling, Injection site pruri...
# 7  [Pain in extremity, Burning sensation, Fatigue...
# 8                              [Chills, Pollakiuria]
# 9  [Vaccination site bruising, Pain in extremity,...

# %%
eval_df_peft.to_csv(os.path.join(results_dir, f'{model_name}-peft-results.csv'), index=False)
