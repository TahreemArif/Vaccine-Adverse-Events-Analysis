# %%
# !pip install transformers datasets evaluate accelerate torch sacremoses peft gdown openpyxl
# !pip install pyarrow==15.0.2
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.9)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 16.4 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 10.0 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 50.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 20.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, sacremoses, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 sacremoses-0.1.1 xxhash-3.5.0
# Collecting pyarrow==15.0.2
#   Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<2,>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow==15.0.2) (1.26.4)
# Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 55.4 MB/s eta 0:00:00
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
# Successfully installed pyarrow-15.0.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import os
import json
import pandas as pd
import numpy as np

from ast import literal_eval

# %%
base_dir = '/content/drive/MyDrive/NLP/vaers_analysis'
data_dir = os.path.join(base_dir, 'data')
results_dir = os.path.join(base_dir, 'results')
models_dir = os.path.join(base_dir, 'models')
runs_dir = os.path.join(base_dir, 'runs')

# %%
data = pd.read_csv(os.path.join(data_dir, 'train_vaers_data.csv'))
data['symptoms'] = data['symptoms'].apply(literal_eval)
data['ordered_symptoms'] = data['ordered_symptoms'].apply(literal_eval)
data.head()
# Out:
#    vaers_id  year         vax_type vax_manu  \
# 0   1563876  2021  COVID19          MODERNA
# 1   1121903  2021  COVID19          MODERNA
# 2   2501590  2022  COVID19          MODERNA
# 3   1228802  2021  COVID19          MODERNA
# 4   1666419  2021  COVID19          MODERNA
#
#                                         symptom_text  \
# 0  increase in blood pressure; Knot on right arm;...
# 1  The day after the vaccine, I had extreme fatig...
# 2  Narrative: Patient was not previously COVID-19...
# 3  Several minutes after receiving 1st dose of Mo...
# 4  Patient is an 86-year-old woman with a history...
#
#                                             symptoms  \
# 0  [Blood pressure increased, Muscle twitching, U...
# 1  [Chills, Fatigue, Headache, Injection site pai...
# 2                     [Death, Fall, Wheelchair user]
# 3  [Fall, Loss of consciousness, Syncope, Unrespo...
# 4  [Aphasia, COVID-19, Confusional state, Mental ...
#
#                                     ordered_symptoms  report_length  \
# 0  [Urticaria, Vaccination site mass, Muscle twit...            234
# 1  [Injection site pain, Rash erythematous, Fatig...             96
# 2                     [Fall, Wheelchair user, Death]             98
# 3  [Loss of consciousness, Syncope, Unresponsive ...            112
# 4  [Respiratory symptom, COVID-19, SARS-CoV-2 tes...            212
#
#    num_symptoms
# 0             4
# 1             7
# 2             3
# 3             4
# 4             8

# %% [markdown]
# ## Data Preparation for PEFT:

# %%
import os
import json
import math
import pandas as pd
import matplotlib.pyplot as plt

import torch
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    TrainingArguments,
    Trainer
)

from datasets import Dataset, DatasetDict

# %%
model_name = 'biobart-v2-large'
model_vendor = 'GanjinZero'
output_dir = os.path.join(runs_dir, model_name)
peft_model_path = os.path.join(models_dir, model_name)

# %%
def create_prompts(row):
    instruction = 'Order the symptoms in chronological order based on the timeline implied in the text. Think step by step to determine the timeline for each symptom.'
    prompt = f"{instruction}\n\nText: {row['symptom_text']}\n\nSymptoms: {row['symptoms']}\n\nOrdered Symptoms:"
    return prompt

# %%
## Convert symptoms into a string with comma separated symptoms
data['symptoms'] = data['symptoms'].apply(lambda symptoms: ', '.join(symptoms))
data['output_text'] = data['ordered_symptoms'].apply(lambda symptoms: ', '.join(symptoms))
data['input_text'] = data.apply(create_prompts, axis=1)

# %%
train_dataset = Dataset.from_dict({
    'input_text': data['input_text'].to_list(),
    'output_text': data['output_text'].to_list()
})

train_valid_spt = train_dataset.train_test_split(test_size=0.1, seed=42)

train_dataset = DatasetDict({
    'train': train_valid_spt['train'],
    'validation': train_valid_spt['test'],
})
train_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 9000
#     })
#     validation: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 1000
#     })
# })

# %% [markdown]
# ## Model Finetuning:

# %%
tokenizer = AutoTokenizer.from_pretrained(f'{model_vendor}/{model_name}') #("facebook/bart-large")
model = AutoModelForSeq2SeqLM.from_pretrained(f'{model_vendor}/{model_name}') #("facebook/bart-large")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/892k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.77G [00:00<?, ?B/s]

# %%
def tokenize(data, tokenizer):
    tokenized_data = tokenizer(data['input_text'], padding='max_length', max_length=1024, truncation=True, return_tensors='pt')
    tokenized_data['labels'] = tokenizer(data['output_text'], padding='max_length', max_length=128, truncation=True, return_tensors='pt').input_ids
    return tokenized_data

fn_kwargs={"tokenizer": tokenizer}
tokenized_dataset = train_dataset.map(tokenize, batched=True, fn_kwargs=fn_kwargs)
tokenized_dataset = tokenized_dataset.map(lambda examples: examples, remove_columns=['input_text', 'output_text'])
tokenized_dataset
# Out:
# Map:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 9000
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })

# %%
from peft import LoraConfig, TaskType, get_peft_model
from transformers import EarlyStoppingCallback

peft_config = LoraConfig(
    r=16,
    bias='none',
    lora_alpha=32,
    lora_dropout=0.05,
    task_type=TaskType.SEQ_2_SEQ_LM,
    #finetuning the attention layers only
    target_modules=['q_proj', 'k_proj', 'v_proj']
)

peft_training_args = TrainingArguments(
    output_dir=output_dir,
    auto_find_batch_size=True,
    learning_rate=1e-3,
    num_train_epochs=10,
    max_steps=10000,
    warmup_steps=500,
    weight_decay=0.01,
    eval_strategy='steps',
    save_strategy='steps',
    logging_steps=100,
    eval_steps=100,
    save_steps=100,
    load_best_model_at_end=True
)

# %%
peft_model = get_peft_model(model, peft_config)

peft_trainer = Trainer(
    model=peft_model,
    args=peft_training_args,
    train_dataset=tokenized_dataset['train'],
    eval_dataset=tokenized_dataset['validation'],
    tokenizer=tokenizer,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=10)]  # Stop if no improvement for 10 Steps
)
# Out:
# <ipython-input-15-c32b4bc41c25>:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   peft_trainer = Trainer(
# max_steps is given, it will override any value given in num_train_epochs

# %%
peft_model.print_trainable_parameters()
# Out:
# trainable params: 3,538,944 || all params: 445,809,664 || trainable%: 0.7938

# %%
peft_trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241207_210454-aw06h2px</code>
# Syncing run <strong><a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface/runs/aw06h2px' target="_blank">/content/drive/MyDrive/NLP/vaers_analysis/runs/biobart-v2-large</a></strong> to <a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface' target="_blank">https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface</a>
#  View run at <a href='https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface/runs/aw06h2px' target="_blank">https://wandb.ai/tahreemarif34-stevens-institute-of-technology/huggingface/runs/aw06h2px</a>
#     <div>
#
#       <progress value='3100' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3100/10000 1:54:52 < 4:15:51, 0.45 it/s, Epoch 2/9]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.904900</td>
#       <td>0.118931</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.112500</td>
#       <td>0.079238</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.093600</td>
#       <td>0.079525</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.088000</td>
#       <td>0.068886</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.082800</td>
#       <td>0.064820</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.082000</td>
#       <td>0.071433</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.076600</td>
#       <td>0.068520</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.075600</td>
#       <td>0.075469</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.082000</td>
#       <td>0.064739</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.082900</td>
#       <td>0.061774</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.071900</td>
#       <td>0.062417</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.076700</td>
#       <td>0.076476</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.071500</td>
#       <td>0.065685</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.085800</td>
#       <td>0.069180</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.079500</td>
#       <td>0.060121</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.071800</td>
#       <td>0.065468</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.073700</td>
#       <td>0.059144</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.068900</td>
#       <td>0.057503</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.067400</td>
#       <td>0.060030</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.063500</td>
#       <td>0.064040</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.060900</td>
#       <td>0.053856</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.062100</td>
#       <td>0.058645</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.064700</td>
#       <td>0.057132</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.053300</td>
#       <td>0.056536</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.056000</td>
#       <td>0.054663</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.054700</td>
#       <td>0.060728</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.069800</td>
#       <td>0.056286</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.059200</td>
#       <td>0.055872</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.060500</td>
#       <td>0.053917</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.056400</td>
#       <td>0.055150</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.053200</td>
#       <td>0.055207</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3100, training_loss=0.09879352246561358, metrics={'train_runtime': 9137.95, 'train_samples_per_second': 8.755, 'train_steps_per_second': 1.094, 'total_flos': 5.42834272763904e+16, 'train_loss': 0.09879352246561358, 'epoch': 2.7555555555555555})

# %%
## Save the model
peft_trainer.model.save_pretrained(peft_model_path)
tokenizer.save_pretrained(peft_model_path)
# Out:
# ('/content/drive/MyDrive/NLP/vaers_analysis/models/biobart-v2-large/tokenizer_config.json',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/biobart-v2-large/special_tokens_map.json',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/biobart-v2-large/vocab.json',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/biobart-v2-large/merges.txt',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/biobart-v2-large/added_tokens.json',
#  '/content/drive/MyDrive/NLP/vaers_analysis/models/biobart-v2-large/tokenizer.json')

# %% [markdown]
# ## Inference:

# %%
from peft import PeftModel, PeftConfig

# %%
test_dataset = pd.read_csv(os.path.join(data_dir, 'test_vaers_data.csv'))
test_dataset['symptoms'] = test_dataset['symptoms'].apply(literal_eval)
test_dataset['ordered_symptoms'] = test_dataset['ordered_symptoms'].apply(literal_eval)
test_dataset['input_text'] = test_dataset.apply(create_prompts, axis=1)
test_dataset['output_text'] = test_dataset['ordered_symptoms'].apply(lambda symptoms: ', '.join(symptoms))
test_dataset.head()
# Out:
#    vaers_id  year         vax_type vax_manu  \
# 0   1344132  2021  COVID19          MODERNA
# 1   1842147  2021  COVID19          MODERNA
# 2   1165207  2021  COVID19          MODERNA
# 3   1618374  2021  COVID19          MODERNA
# 4   2460242  2022  COVID19          MODERNA
#
#                                         symptom_text  \
# 0  A few days after my vaccine, I noticed under t...
# 1  Period schedule on and off the chart; Increase...
# 2  within 24 hours of receiving my 2nd dose, I fi...
# 3  Side effects seem to have cleared up by the 17...
# 4  I received my first Moderna vaccine on one/14/...
#
#                                             symptoms  \
# 0                                [Blister, Erythema]
# 1  [Biopsy, Heavy menstrual bleeding, Menstrual d...
# 2  [Chills, Dry eye, Eye pain, Fatigue, Headache,...
# 3               [Headache, Vaccination complication]
# 4  [Amenorrhoea, Arthralgia, Carbohydrate antigen...
#
#                                     ordered_symptoms  report_length  \
# 0                                [Blister, Erythema]             93
# 1  [Menstrual disorder, Heavy menstrual bleeding,...            259
# 2  [Pyrexia, Chills, Headache, Myalgia, Neuralgia...            110
# 3               [Vaccination complication, Headache]            241
# 4  [Lymphadenopathy, Arthralgia, Pain in extremit...            162
#
#    num_symptoms                                         input_text  \
# 0             2  Order the symptoms in chronological order base...
# 1             4  Order the symptoms in chronological order base...
# 2             9  Order the symptoms in chronological order base...
# 3             2  Order the symptoms in chronological order base...
# 4            12  Order the symptoms in chronological order base...
#
#                                          output_text
# 0                                  Blister, Erythema
# 1  Menstrual disorder, Heavy menstrual bleeding, ...
# 2  Pyrexia, Chills, Headache, Myalgia, Neuralgia,...
# 3                 Vaccination complication, Headache
# 4  Lymphadenopathy, Arthralgia, Pain in extremity...

# %%
def batch_inference(model, tokenizer, test_prompts, batch_size=5):
    """
    Performs batch inference on a list of prompts using a pre-trained model and tokenizer.

    This function processes the prompts in batches to efficiently handle large datasets,
    tokenizes the input, and generates predictions using the model. It returns the decoded
    predicted sequences.

    Args:
        model (torch.nn.Module): The pre-trained model to use for inference (e.g., GPT, T5, etc.).
        tokenizer (PreTrainedTokenizer): The tokenizer associated with the model for encoding inputs and decoding outputs.
        test_prompts (list of str): List of input prompts to generate predictions for.
        batch_size (int, optional): The number of prompts to process in each batch. Default is 5.

    Returns:
        list of str: A list of decoded predicted sequences corresponding to the input prompts.

    Raises:
        Exception: Catches and reports errors encountered during batch processing.

    Notes:
        - The function uses GPU if available; otherwise, it defaults to CPU.
        - Each batch is tokenized with padding and truncation up to a maximum input length of 1024 tokens.
        - Model generates predictions with up to 128 new tokens using beam search with 5 beams.
        - Any exceptions during batch processing are caught, and the function proceeds with the next batch.
    """
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = model.to(device)
    predicted_sequence = []
    num_batches = math.ceil(len(test_prompts) / batch_size)

    for i in range(num_batches):
        try:
            # Prepare the batch of prompts
            batch = tokenizer(
                test_prompts[i * batch_size:(i + 1) * batch_size],
                padding='max_length',
                max_length=1024,
                truncation=True,
                return_tensors='pt'
            ).to(device)

            # Generate predictions
            encoded_sequence = model.generate(**batch, max_new_tokens=128, num_beams=5)

            # Decode the predictions
            predicted_sequence.extend(tokenizer.batch_decode(encoded_sequence, skip_special_tokens=True))

        except Exception as e:
            # Handle errors for the batch
            print(f'Error in batch {i}: {e}')
            continue

        print(f'Processed Batch: {i} successfully!!')

    return predicted_sequence

# %%
def create_eval_df(test_dataset, predicted_sequence, true_sequence_key='output_text',
                   symptom_text_key='symptom_text', prompt_key='input_text'):
    """
    Creates an evaluation DataFrame by processing true and predicted sequences from the dataset.

    Args:
        test_dataset (pd.DataFrame): The dataset containing test inputs and expected outputs.
        predicted_sequence (list): The list of predicted sequences.
        true_sequence_key (str): The column key in `test_dataset` for the true sequence. Default is 'output_text'.
        symptom_text_key (str): The column key in `test_dataset` for the symptom text. Default is 'symptom_text'.
        prompt_key (str): The column key in `test_dataset` for the prompts. Default is 'input_text'.

    Returns:
        pd.DataFrame: Processed evaluation DataFrame with cleaned true and predicted sequences.
    """
    # Create the evaluation DataFrame
    eval_df = pd.DataFrame({
        'symptom_text': test_dataset[symptom_text_key].to_list(),
        'prompt': test_dataset[prompt_key].to_list(),
        'true_sequence': test_dataset[true_sequence_key].to_list(),
        'predicted_sequence': predicted_sequence
    })

    # Process and clean the true and predicted sequences
    eval_df['true_sequence'] = eval_df['true_sequence'].apply(lambda sym: [s.strip() for s in sym.split(',')])
    eval_df['predicted_sequence'] = eval_df['predicted_sequence'].apply(lambda sym: [s.strip().strip("'\"") for s in sym.split(',')])

    return eval_df

# %% [markdown]
# ### Inference Using Bio BART Without PEFT:

# %%
# Step 1: Load the pre-trained sequence-to-sequence model
base_model = AutoModelForSeq2SeqLM.from_pretrained(f'{model_vendor}/{model_name}')

## Step 2: Perform batch inference using the loaded model
predicted_sequence_wpeft = batch_inference(base_model, tokenizer, test_dataset['input_text'].to_list())

## Step 3: Create a DataFrame for evaluation
eval_df_wpeft = create_eval_df(test_dataset, predicted_sequence_wpeft)
eval_df_wpeft[['symptom_text', 'true_sequence', 'predicted_sequence']].head(10)
# Out:
# Processed Batch: 0 successfully!!
# Processed Batch: 1 successfully!!
# Processed Batch: 2 successfully!!
# Processed Batch: 3 successfully!!
# Processed Batch: 4 successfully!!
# Processed Batch: 5 successfully!!
# Processed Batch: 6 successfully!!
# Processed Batch: 7 successfully!!
# Processed Batch: 8 successfully!!
# Processed Batch: 9 successfully!!
# Processed Batch: 10 successfully!!
# Processed Batch: 11 successfully!!
# Processed Batch: 12 successfully!!
# Processed Batch: 13 successfully!!
# Processed Batch: 14 successfully!!
# Processed Batch: 15 successfully!!
# Processed Batch: 16 successfully!!
# Processed Batch: 17 successfully!!
# Processed Batch: 18 successfully!!
# Processed Batch: 19 successfully!!
# Processed Batch: 20 successfully!!
# Processed Batch: 21 successfully!!
# Processed Batch: 22 successfully!!
# Processed Batch: 23 successfully!!
# Processed Batch: 24 successfully!!
# Processed Batch: 25 successfully!!
# Processed Batch: 26 successfully!!
# Processed Batch: 27 successfully!!
# Processed Batch: 28 successfully!!
# Processed Batch: 29 successfully!!
# Processed Batch: 30 successfully!!
# Processed Batch: 31 successfully!!
# Processed Batch: 32 successfully!!
# Processed Batch: 33 successfully!!
# Processed Batch: 34 successfully!!
# Processed Batch: 35 successfully!!
# Processed Batch: 36 successfully!!
# Processed Batch: 37 successfully!!
# Processed Batch: 38 successfully!!
# Processed Batch: 39 successfully!!
# Processed Batch: 40 successfully!!
# Processed Batch: 41 successfully!!
# Processed Batch: 42 successfully!!
# Processed Batch: 43 successfully!!
# Processed Batch: 44 successfully!!
# Processed Batch: 45 successfully!!
# Processed Batch: 46 successfully!!
# Processed Batch: 47 successfully!!
# Processed Batch: 48 successfully!!
# Processed Batch: 49 successfully!!
# Processed Batch: 50 successfully!!
# Processed Batch: 51 successfully!!
# Processed Batch: 52 successfully!!
# Processed Batch: 53 successfully!!
# Processed Batch: 54 successfully!!
# Processed Batch: 55 successfully!!
# Processed Batch: 56 successfully!!
# Processed Batch: 57 successfully!!
# Processed Batch: 58 successfully!!
# Processed Batch: 59 successfully!!
# Processed Batch: 60 successfully!!
# Processed Batch: 61 successfully!!
# Processed Batch: 62 successfully!!
# Processed Batch: 63 successfully!!
# Processed Batch: 64 successfully!!
# Processed Batch: 65 successfully!!
# Processed Batch: 66 successfully!!
# Processed Batch: 67 successfully!!
# Processed Batch: 68 successfully!!
# Processed Batch: 69 successfully!!
# Processed Batch: 70 successfully!!
# Processed Batch: 71 successfully!!
# Processed Batch: 72 successfully!!
# Processed Batch: 73 successfully!!
# Processed Batch: 74 successfully!!
# Processed Batch: 75 successfully!!
# Processed Batch: 76 successfully!!
# Processed Batch: 77 successfully!!
# Processed Batch: 78 successfully!!
# Processed Batch: 79 successfully!!
# Processed Batch: 80 successfully!!
# Processed Batch: 81 successfully!!
# Processed Batch: 82 successfully!!
# Processed Batch: 83 successfully!!
# Processed Batch: 84 successfully!!
# Processed Batch: 85 successfully!!
# Processed Batch: 86 successfully!!
# Processed Batch: 87 successfully!!
# Processed Batch: 88 successfully!!
# Processed Batch: 89 successfully!!
# Processed Batch: 90 successfully!!
# Processed Batch: 92 successfully!!
# Processed Batch: 93 successfully!!
# Processed Batch: 94 successfully!!
# Processed Batch: 95 successfully!!
# Processed Batch: 96 successfully!!
# Processed Batch: 97 successfully!!
# Processed Batch: 98 successfully!!
# Processed Batch: 99 successfully!!
#                                         symptom_text  \
# 0  A few days after my vaccine, I noticed under t...
# 1  Period schedule on and off the chart; Increase...
# 2  within 24 hours of receiving my 2nd dose, I fi...
# 3  Side effects seem to have cleared up by the 17...
# 4  I received my first Moderna vaccine on one/14/...
# 5  Patient experienced only chills; Fever; Sorene...
# 6  8 days after the first vaccine dose, I had itc...
# 7  Sore arm; Very tired; Headache; Burning sensat...
# 8  Chills; Urinating (More often); This spontaneo...
# 9  Swelling Left arm, upper Calves and legs swell...
#
#                                        true_sequence  \
# 0                                [Blister, Erythema]
# 1  [Menstrual disorder, Heavy menstrual bleeding,...
# 2  [Pyrexia, Chills, Headache, Myalgia, Neuralgia...
# 3               [Vaccination complication, Headache]
# 4  [Lymphadenopathy, Arthralgia, Pain in extremit...
# 5                         [Chills, Pyrexia, Myalgia]
# 6  [Injection site pruritus, Injection site swell...
# 7  [Burning sensation, Headache, Pain in extremit...
# 8                              [Chills, Pollakiuria]
# 9  [Peripheral swelling, Vaccination site bruisin...
#
#                                   predicted_sequence
# 0  [Order the symptoms in chronological order bas...
# 1  [Order the symptoms in chronological order bas...
# 2  [Order the symptoms in chronological order bas...
# 3  [Order the symptoms in chronological order bas...
# 4  [Order the symptoms in chronological order bas...
# 5  [Order the symptoms in chronological order bas...
# 6  [Order the symptoms in chronological order bas...
# 7  [Order the symptoms in chronological order bas...
# 8  [Order the symptoms in chronological order bas...
# 9  [Order the symptoms in chronological order bas...

# %%
predicted_sequence_wpeft
# Out:
# ['Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: A few days after my vaccine, I noticed under the pad of my big toe, there was a yellowish fluid-filled lesion that was about a month to 2 months to resolve. I also had redness onthe tip of a couple of my toes and the end of my lower and middle toeses. That was on my left foot. I  also had red on',
#  'Order the symptoms in chronological order based on the timeline implied in the-text. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: Period schedule on and off the chart; Increased period bleeding; She experienced was headache which was resolved day after getting vaccine; This spontaneous case was reported by a consumer and describes the occurrence of MENSTRUAL DISORDER (Period schedule on\xa0and off\xa0the chart), HEAVY MENSTRULAR BLEEDING (Increased period blood) and THERAPEUTIC RESPONSE UNEXPECT',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the optimal order for each symptom.Nitrome¯¯¯¯Text: within 24 hours of receiving my 2nd dose, I first experienced common side effects: fever, chills, headache, muscle pain, nerve pain, severe fatigue, etc. However, around 8:00 PM 27 hours after vaccination, I began experiencing strange and severe pain/pressure around my eyes - especially above my eye below the brow bone. It has now been three days since vaccination and the pain has not subs',
#  'Order the symptoms in chronological order based on the timeline implied in the present text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Side effects seem to have cleared up by the 17th; Weird burst of pain on  the left side of my head; This spontaneous case was reported by a consumer and describes the occurrence of VACCINATION COMPLICATION (Side effects seem not to has cleared up at the17th) and HEADACHE (Weird burst of pressure on time of my heart) in a',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: I received my first Moderna vaccine on one/14/21, the second on 2/11/21 and booster on 1/12/22. I work in public health and was on then the front lines of treatment for this pandemic. I experienced significant lower extremity lymphatic swelling with each injection, that was the most significant of which occurred with the first and second injection in ',
#  'Order the symptoms in chronological order based on the timeline implied in the present case report. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Patient experienced only chills; Fever; Soreness in her arms; This spontaneous case was reported by a consumer and describes the occurrence of CHILLS (Patient experienced onlyills), PYREXIA (Fever) and MYALGIA (Soreness In her arms) in a female patient of an unknown age who received mRNA-1273 (Moderna COVID-19 Vaccine) (batch no',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the optimal\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: 8 days after the first vaccine dose, I had itching, swelling, redness, and warmth at injection site on my right upper arm when I woke up in this morning. This isthe first day I have had these symptoms.  The swelling and redness is about 4 inches in diameter and is very firm. The symptoms have stayed the same all day and the swelling has not gone down yet. ',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that time for each symptom.¯¯¯¯¯¯¯¯Text: Sore arm; Very tired; Headache; Burning sensation; This spontaneous case was reported by a consumer and describes the occurrence of PAIN IN EXTREMITY (Sore arm), BURNING SENSATION (Burning sensation), FATIGUE (Very tib) and HEADACHE (Headache) in a 67-year-old male patient who received mRNA-1273 (Moderna COVID-',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: Chills; Urinating (More often); This spontaneous case was reported by a consumer and describes the occurrence of CHILLS (Chills) and POLLAKIURIA (Urinating ( More often)) in a 79-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.     No Medical History information was reported.    On 15-Feb-',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: Swelling Left arm, upper Calves and legs swelling; Bruise/ Lump on  the injection Site; Sore Arm; Itching all over the body and injection site; upper Calves, legs swelling and Asthma attack; Anxiety; Stomach Cramps; stomach Bloating; Runny Nose; Weak / Tired eyes; Fatigue; Headache; This spontaneous case was reported by a consumer and describes the',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical scenario. Think step by step to determine the specific order for each symptom.Nitrome¯¯¯¯Text: Patient is a 59 y.o. male with schizophrenia, anxiety, HLD, CKD, DM, hypothyroidism, and hx of CVA.  He presents as a transfer after being found to have COVID19 at his group home.  She is not able to provide any hx surrounding his current state due to cognitive dysfunction and underlying mental health issues in addition to prior CVA. .  Apparently',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.¯¯¯¯¯¯¯¯Text: Severe neuropathy; feels the pain is affecting her entire lower body; Feeling pain inthe spine; This spontaneous case was reported by a consumer and describes the occurrence of NEUROPATHY PERIPHERAL (Severe neuropathy) in a 53-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) (batch no. 037B21A) for COVID-',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that temeline for each symptom.ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¯¯¯¯Text: Approximately 5 minutes after receiving booster dose, the left side of the patient's face started tingling  and felt numb.  She said  this happened with the first dose, but was more intense-lasting 90 minutes, and that it did not happen with  the second. She didn't have any obvious swelling/inflammation,  redness, or difficulty moving the area.  Her",
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: Vomiting; little bit of a sore arm; had no appetite; diarrhea; exhausted; This spontaneous case was reported by a consumer and describes the occurrence of PAIN IN EXTREMITY (little bit of an sore arm), DECREASED APPETITE (had no appetite), DIARRHOEA (diarrhea), FATIGUE (exhausted) and VOMITING (Vomiting) in a 79-',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the exact chronological order for each symptom.¯¯¯¯¯¯¯¯Text: After  I received my booster, my lymph nodes onthe left side (same side I received our injection) were very swollen and remained so for weeks.  Three weeks after receiving it, I had a substantial allergic reaction (hives, oozing, scabbing, swelling) to the same hair dye I?ve been using for a long time.  I can no longer dye my hair, and my',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine  timelines for each symptom.Nitrome¯¯¯¯Text: Headache, Fever, Diarrhea,  Swelling at the injection site, chills, sinus headache with neck pain. Fever up  to 102.9 degrees F Narrative:  She has been taking Motrin 400 mg Q6H and Tylenol 1000 mg  Q4H for the fever 102.5-102.9 degree F. The fever/chills and headache  developed 15 hours post',
#  "Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the exact order for each symptom.¯¯¯¯¯¯¯¯Text: Felt like sleeping all day; Rash; Fever; Muscle pain; chills; Nausea; A spontaneous report was received from a consumer concerning a 77-years-old female patient who received Moderna's COVID-19 vaccine (mRNA-1273) and experienced events fever, muscle pain, chills, nausea and somnolescence.  The patient's medical history was not provided. No relevant concomitant medications were reported.  On",
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: tongue tingled; half her mouth had a tingling feeling; half its mouth had numbness; flu-like symptoms; arm ached; This spontaneous case was reported by a nurse and describes the occurrence of PARAESTHESIA ORAL (tongue Ttingled), ParaESTHASIA ORal (half her mouth has a tling feeling), HYPOAESTHES',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine and then repeat the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: Systemic: pt said he's now having phobias and suspicions and other symptoms but would not clarify further-Severe, Additional Details: Pt was very angry when he called on 4/3/23 and said after he received the vaccine on 6/18/2022 he went home and took a nap and after he woke up is when the Symptoms began and they have continued since",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical vignette. Think step by step to determine the exact chronological order for each symptom.Nitrome¯¯¯¯Text: Patient was in her usual state of health at the\xa0time of receiving her Moderna booster on 1/18/22. Patient reports receiving the vaccine via IM injection into the left shoulder and within a few hours she developed shoulder pain. Pain has persisted to include throbbing, reduced ROM, effect on daily activities and work, and waking from sleep. These symptoms have been present for 12 days post administration',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine and then repeat the chronological order for each symptom.Nitrome¯¯¯¯Text: Received the Booster on 12/23 injection sight was sore as expected however, work up 12/26 at 6am and injection sight has become swollen, very red, and hot to the-touch.  it is now itching.  I've been applying ice and antibiotic cream tothe injection sight.  Was taking Benadryl however, caused sinus headaches so, am ",
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: Tested positive for COVID-19; sweating; headache; sore throat; fever; sore arm; body aches; fatigue; This spontaneous case was reported by a consumer and describes the occurrence of SARS-COV-2 TEST POSITIVE (Tested positive for COVD-19) and HYPERHIDROSIS (sweating) in a 52-year-old male patient who received mRNA-1273',
#  "Order the symptoms in chronological order based on the timeline implied in the literature. Think step by step to determine the optimal order for each symptom.¯¯¯¯¯¯¯¯Text: I've been experiencing joint pain all over, especially in my spine and my hips. Mainly my neck and my lower back and right hip. I had x-rays done and an MRI of both my neck or lower back, and I guess from what they said, it's normal degenerative arthritis. They put me through physical therapy to see if there was any change and there is no change. I",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that temeline for each symptom.¯¯¯¯¯¯¯¯Text: Right leg was swollen from her hip to the lower two toes; Soreness of arm; This spontaneous case was reported by a patient and describes the occurrence of PAIN IN EXTREMITY (Sorefulness of arm) and PERIPHERAL SWELLING (Right leg was swelling from her hto two below the knee and from the right hip) in an 89',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: I had received 2 Pfizer doses previously. Typical body aches, sore arm occurred with both. I opted for Moderna as my booster shot. I had similar symptoms with it lasting 24 hours. After the booster and before 12/09, I had 3 menstrual cycles. In talking with a worker, they felt I should submit this to VAERS. The following month, I have 2 menstrual cycles',
#  'Order the symptoms in chronological order based on the timeline implied in this text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Site: Itching at Injection Site-Medium, Site: Redness at injection Site-medium, Systemic: Allergic: Itch (specify: facial area, extremeties)-Medium, Systemic; Allergic: Rash Generalized-Medium. Additional Details: Patient called on 9/21/21 regarding long term hives and itching after vaccine. Patient was advised to take a benadryl to help with',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: Brain fog / same thing happened when taking the Moderna vaccine for a booster; Bedridden / same\xa0thing happened  when targeting the moderna vaccine and then taking it to the bedridden / Same thing occurred when the patient tried to be bedridden; Headache / same -thing happened after taking a Moderna dose for a  booster; Fever / same',
#  "Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine  timelines for each symptom.Nitrome¯¯¯¯Text: One week after injection I developed Right sided facial numbness, right eye and facial drooping. Seen in ER and diagnosed with Bell's  Palsy.  Treated with Prednisone 60 mg qd for one week and Valtrex 1 Gm tid for one month. I am completing treatment today, March 10, 2021, with no improvement. Follow up visit with my provider is scheduled for March15,20",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: Blood pressure high; puffy at injection site; red at injection sites; itchy at injection system; This spontaneous case was reported by a consumer and describes the occurrence of HYPERTENSION (Blood pressure high), INJECTION SITE SWELLING (puffy at Injection site), INjectION Site ERYTHEMA (red at injection size) and INJECTion SITE PRURIT',
#  "Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the optimal\xa0timeline for each symptom.Nitrome¯¯¯¯Text: Large red swelling the size of a silver dollar.  Hot to touch, became very itchy.  Applied benadryl tothe site and then took one antihistamine pill after the second or third day.  That helped and while it is still red it doesn't itch anymore.  It is now about the 10th day after injection.  The swelling and redness is",
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: Red spot in her arm; felt like a be pinch; This spontaneous case was reported by a consumer and describes the occurrence of ERYTHEMA (Red spot in his arm) and PAIN (felt like a been pinch) in a 79-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) (batch no. 012M20A) for COVID- 19 vaccination.    ',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the optimal order for each symptom.Nitrome¯¯¯¯Text: Patient stated on 4/17 (approximately 4 days after receiving shot) she got a rash on her left arm.  The rash started  in  the same area as the shot and continued over time   almost to her elbow.  She reported this to the pharmacy on 04/23/2021 and at that time the rash was improving. Patient stated the skin itched',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the optimal time for each symptom.¯¯¯¯¯¯¯¯Text: I have had tinnitus for years but it has never really bothered me or affected my day to day life.  The day after receiving the Moderna vaccine my tinninnitus  was significantly worse (louder and more high-pitched) and I am now aware of it constantly. It has continued at the same increased level to this day. I?m sure I?ll manage but',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: Approximately 1200 ,Pt answered no to all pre_vaccination questions. Pt. eyes closed and head dropped to right immediately after first dosed of Moderna #0032A21A was given in his in his L deltoid.  Pt immediately came back to arousal after securing pt upright by  his shoulder. STAT call for assistance.  Onsite doctor called STAT site lead RN present Pt stated, Local',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the exact chronological order for each symptom.¯¯¯¯¯¯¯¯Text: On day 10, a large lesion appeared around the injection site.  It was 4 inches long and 2.5 inches wide, hot to the skin, itchy, swollen and hard.  This is not an uncommon reaction for me.  The same happens after flu shots.  There was no difference was the lag in reaction from vaccination. The lesion grew over a couple of days, but lessened in',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the optimal chronological order for each symptom.NitromecffffText: 04/11 (Day 4 after 2nd shot) - Scratchy throat starting, some cough 04/12 (Day 5) - sore thorax, cough, fatigue, headache, fever overnight, Metallic taste in mouth.  Got worse throughout the day. 04/13 (Day 6) - heavy cough, sore throroat, fever, chills, heavy fatigue, Metallic',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¯¯¯¯Text: Patient experienced fainting and fell to the floor .  She claimed to have a rapid heart beat but her blood pressure was 106/59 with a pulse of 69.  She felt dizzy for 40 minutes. She stated she wanted fresh air and something to eat.  We offered bottled water and crackers. .  He spit the crackers out stating she did not like the flavor. ',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.¯¯¯¯¯¯¯¯Text: Arm itched a little bit; Rash; Arm started swelling- in  the shot area; This spontaneous case was reported by a consumer and describes the occurrence of INJECTION SITE PRURITUS (Arm itched A little bit), INJECTion SITE RASH (Rash) and INJECTIONS SITE SWELLING (Arm started swelling - in that shot area) in a 70',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: chest feels tight; fever; chills; This spontaneous case was reported by a consumer and describes the occurrence of CHEST DISCOMFORT (chest feels ttight), PYREXIA (fever) and CHILLS (chills) in a female patient of an unknown age who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.     No Medical History information was',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine  timelines for each symptom.Nitrome¯¯¯¯Text: While technician finished administering the vaccine , patient had seizure like reaction that lasted for about 15 seconds . Patient immediately gained consciousness and had no recollection of what happened. He waited for 30 minutes and totally fine. Prior to giving the shot, patient checked  the box for feeling dizzy after vaccinations, when I inquired about it , he said that was years back and he had no issues',
#  'Order the symptoms in chronological order based on the timeline implied in the present text. Think step by step to determine and then repeat the order for each symptom.Nitrome¯¯¯¯Text: Feeling miserable all day; Headache; Nausea; Body ache; Fatigue; Fever; This spontaneous case was reported by a consumer and describes the occurrence of FEELING ABNORMAL (Feeling miserable all Day), HEADACHE (Headache), NAUSEA (Nausea), MYALGIA (Body ache) and FATIGUE (Fatigue) in an 83-year-',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the duration of each symptom.¯¯¯¯¯¯¯¯Text: arm pain; body ache; fatigue; This spontaneous case was reported by a patient and describes the occurrence of PAIN IN EXTREMITY (arm pain), MYALGIA (body ache) and FATIGUE (fatigue) in a 73-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 prophylaxis.     The patient was never diagnosed with COVID',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: Itchiness at back of neck and wrists which then spread throughout entire body.  Warmness in ears/burning sensation.  Skin irritation lead to hive like bumps and dermographia.  Symptoms flare whenever skin is agitated by anything stronger/denser than clothing .  Able to be managed by taking one antihistamine per day - currently Allegra 24 hour.  At date of report,',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the occurrence of each symptom.¯¯¯¯¯¯¯¯Text: It was so restless I was afraid for my heart/got restless/ restlessness increased; Was so restless that he was afraid to go to sleep; Became hyper; Felt nervous; Founded insecure; Very fast in my thinking; Shivering and couldn't stop it; This spontaneous case was reported by a consumer and describes the onset of RESTLESSNESS (It was so disruptive I was fear for my hand",
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Started feeling sick to stomach and fever around 9:30 a.m. on 3/12/2021.  Fever stayed from 100.4 to 102.8 until 3/14/20 21 around 3:30 A. m.  Very swollen around left arm and around left side of neck with a swollen knot at my collar bone and it is bruised.  Arm, neck, and collar bone area',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the correct timelines for each symptom.Nitrome¯¯¯¯Text: He was under the care of his mother, due to him being Mentally Handicapped. Approximately 10 to 15 minutes after he received the vaccine both of his forearms started to turn red in color. He stated that they were itching. He had no other adverse reactions. Being he was not short of breath and had no facial or tongue swelling, no nausea or vomiting,',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the exact sequence for each symptom.Nitrome¯¯¯¯Text: Patient brought the ED by EMS on 11/19 early morning for evaluation of a fall. Patient was laying in bed when she rolled off the side of her bad in an unwitnessed fall. Ultimately, she was discharged home however returned to theED that day in  the afternoon after another fall. Person reports she felt dizzy and fell tothe floor. During her second ED visit, she reported',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: Dizziness to a point where driving a motor vehicle would have been unsafe. Occurred initially while swimming (lap swimming, outdoors). Coincided with symptoms of heat exhaustion, to include nausea, weakness, rapid pulse, and profuse sweating. Heat injury symptoms subsided within 1-2 hours. Dizziness continued for 3 days, followed by mild headache for an additional 1 day.¯¯¯¯¯¯¯¯Symptoms: ['",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: arm pain/same symptoms; a little bit of a fever; fatigue; body aches; This spontaneous case was reported by a consumer and describes the occurrence of PAIN IN EXTREMITY (arm pain/ same symptoms), PYREXIA (a little bit a fever), FATIGUE (fatigue) and MYALGIA (body aches) in a 40-year-old female patient who',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the optimal order for each symptom.Nitrome¯¯¯¯Text: Weeks later after the vaccine my hand started randomly shaking and I am unable to write my name. On 2/24 I went to the doctor and they said they can't figure out why my hands keep shaking so they recommended me to go to a neurologist and I have a appointment this upcoming week.NitromecffffSymptoms: ['Dysgraphia', 'Tremor', 'X",
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: Covid arm; red rash size of her hand; redness at injection site; This spontaneous case was reported by a consumer and describes the occurrence of VACCINATION SITE REACTION (Covid arm), RASH ERYTHEMATOUS (red rash sizeof her hand) and VACCinATION Site ERY THEMA (redness at injection system) in a 50-year-old female patient',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the optimal\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: Patient complained of feeling dizzy.  She had blood pressure checked and it was elevated.  Blood pressure did decrease after 15-20 minutes.  Patient was observed by 2 local staff nurses and myself.  They were counseled to speak to her primary care physician as soon as possible.  He was walked to his vehicle by nursing staff.  The vehicle was driven by her sister.  An administrator at',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: Adverse Event: Hives all over the body, persisting for a few hours before disappearing and reappearing later (within another set of hours). Has been occurring since 1/14/2022, so pretty chronic at this point. Not debilitating, but certainly annoying and can lead to very minor bleeding due to scratching.  Treatment: Cetirizine HCL (Generic Brand), 1 x per day.',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical scenario. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: Patient presented with possible seizure activity. Patient has a long known history of seizures but when she had the placement of a vagal nerve simulator seizures have subsided for 2 years. Patient also takes THC/CBD gummies for treatment of her epilepsy. Patient states she hadthe moderna covid vaccine yesterday and has had symptoms of an oncoming seizure today. Patient studies she has also',
#  'Order the symptoms in chronological order based on the timeline implied in the key text. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: The resident resides in an independent living facility/apartment. The reporter at the center was informed by his daughter he was not feeling well on 1/1/2021 (specific symptoms could not be ascertained). He reportedly went to be COVID tested on 1-1/2020 and observed to being deceased in his apartment on 1 /2/2020. I do not have confirmation of his COVID results,',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: sore arm; Headache; Extreme Nausea; This spontaneous case was reported by a consumer and describes the occurrence of PAIN IN EXTREMITY (sore arm), HEADACHE (Headache) and NAUSEA (Extreme Nausea) in a 65-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) (batch nos. 013L20A and 039K20',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: coughing; fever of 100.7 deg; Sickness; vomited; This spontaneous case was reported by a consumer and describes the occurrence of ILLNESS (Sickness), VOMITING (vomited), PYREXIA (fever of 100,7 deg) and COUGH (coughing) in a 55-year-old male patient who received mRNA-1273 (Moderna COVID-',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: For three nights after the first vaccine shot I had flashes of lights in my right eye when I closed them. After three days our right eye became very dry. Since that -time my Right eye is blurry off and on.  After the second vaccine shot both eyes   Ache all time and I se flashes of light off to the sides of my eyes when they are',
#  "Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.NitromeNitromeText: Pt. reported dizziness and nausea approx. 5 minutes after administration. Pt. denied eating sufficiently today. BP: 141/87. HR: 70. pt. didnt know baseline BP.Pt. reported symptom improvement after 15 mins of observation. pt, was given water, food, a damp wet cloth for neck. pt., left 30 minutes after observation reported she felt better.NitromecffffSymptoms: ['Dizziness',",
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0 text. Think step by step to determine the exact sequence for each symptom.Nitrome¯¯¯¯Text: 1406: After receiving COVID vaccine, pt c/o sudden lightheadedness, LE weakness, bilat ear pressure, tingling sensation to nose, HA pressure 1410: BP 118/78 HR 52 RR 16 SpO2 99%  Add. RN called; head of car seat lowered; pt denied CP or SOB.   1417: HR 60 SpO2 98% Missed heart beats noted on auscultation',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine  timelines for each symptom.Nitrome¯¯¯¯Text: While eating breakfast the next morning after my shot, I got dizzy/light-headed and fainted, falling to the floor. I was "out" for ~2 minutes, according to my MD wife. After 2-3 minutes ,I felt fine and went and played tennis 15 Minutes later. I don\'t think that I have never fainted in my life time. I take',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine a timelines for each symptom.¯¯¯¯¯¯¯¯Text: Site: Pain at Injection Site-Medium, Site: Redness at Injection site-Medium/High, Systemic: Skin warmth-High. Site: Swelling at Injection System-Medium. Systemic: Allergic: Rash (specify: facial area, extremeties)-Medium, systemic: Inject site area is swollen-Medium or High, Additional Details: Patient says her arm is swollen and hot to a touch at injection',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the specific timelines for each symptom.Nitrome¯¯¯¯Text: Light Headedness; Pain was over back of his eye sockets to around the\xa0temples and the - top of his head; Mild headaches; This spontaneous case was reported by a consumer and describes the occurrence of DIZZINESS (Light Headedness), EYE PAIN (Pain was over round of his ear sockets and to over the eye sockets, around temples, and ',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the potential for each symptom.Nitrome¯¯¯¯Text: bad heart palpitations; numbness in  the face; issues with hearing (coming and going)/hearing things that are not there; signs of psychosis; seeing illusions; seeing flashes of light in darkness; losing his appetite; tasting chemicals in my mouth; worsening my depression; fatigue; This spontaneous case was reported by a consumer and describes the occurrence of PALPITATIONS (bad heart palpitations), HYPOAES',
#  'Order the symptoms in chronological order based on the timeline implied in the information. Think step by step to determine the exact sequence of each symptom.Nitrome¯¯¯¯Text: chest pain; diarrhea; chills; Headache; This spontaneous case was reported by a consumer and describes the occurrence of CHEST PAIN (chest pain), DIARRHOEA (diarrhea), CHILLS (chills) and HEADACHE (Headache) in a 68-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.     No Medical History',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: This spontaneous case was reported by a consumer and describes the occurrence of VACCINATION SITE WARMTH (warm to the skin), VACCinATION Site PAIN (arm soreness), VaccINATION SPOTUS (arm itching), VINCINATION SUMITUS (Vaccination SITE ERYTHEMA (bright red area about 2.5 inches in diameter) and RASH',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the-timeline for each symptom.¯¯¯¯¯¯¯¯Text: really sick; had lymph nodes; high fever; This spontaneous case was reported by a consumer and describes the occurrence of ILLNESS (really sick), LYMPHADENOPATHY (had lymph nodes) and PYREXIA (high fever) in a female patient of an unknown age who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.     No Medical History information was',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the optimal chronological order for each symptom.Nitrome¯¯¯¯Text: Immediately after I got the shot, I got an awful medicine taste in my mouth.  Then within 5-10 minutes I got a gpober pf phlegm / mucus in my throat.  That phlegm/mucus made me have to spit... then made me blow my nose.  I tongue started to swell... with the swelling moving into the left side',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine  timelines for each symptom.Nitrome¯¯¯¯Text: Approximately  11-12 hours  after receiving my second dose of Moderna?s COVID-19 Vaccine on 2/3/21 (received first dose on 1/6/21), I began suddenly feeling symptoms such as: fatigue, chills, body aches, headache, and fever (103 degrees Fahrenheit). The symptoms came on suddenly/abruptly. The fever lasted approximately 24 hours and the other symptoms lasted approximately 48',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the-timeline for each symptom.Nitrome¯¯¯¯Text: Swelling and soreness in  the arm of the injection site on 04/16/2021. On 05/22/20 21 severe knee pain and joint pain in to the left knee. I saw Dr. on 05/25 /2021, he thought it was arthritis.  Pain medication- tramadol hcl 50 mg, every 6 hrs.  as needed, cream Diclofen',
#  "Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that temeline for each symptom.Nitrome¯¯¯¯Text: I began feeling achy around 4:00 PM.  It progressed to chills, headache, burning eyes, fever.  My fever was 103.2 when I went to bed at midnight.  Between 9:00  PM and midnight I also had difficulty with bladder control.   I slept 12 hours and today I fell 100%.¯¯¯¯¯¯¯¯Symptoms: ['Chills', 'Eye irritation', 'Headache",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that time for each symptom.Nitrome¯¯¯¯Text: Second shot is greater than day 35; COVID-19; This spontaneous case was reported by a nurse and describes the occurrence of INAPPROPRIATE SCHEDULE OF PRODUCT ADMINISTRATION (Second shot is less than or equal to day 35) and COVID- 19 (COVID-19) in an 88-year-old female patient who received mRNA-1273 (Moderna',
#  'Order the symptoms in chronological order based on the timeline implied in  text. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: Within minutes of COVID-19 injection into left arm she felt light headed and developed dry barky,  hacking relentless cough. There was no itching, hives, swelling, GI symptoms, feeling of impending  doom, throat closing, wheezing or hoarseness. She felt more difficulty on breathing out. She reports  pulse ox 98% on RA, elevated BP and normal pulse taken by paramedics.. She used her Xopen',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.NitromeNitromeText: Systemic: Dizziness / Lightheadness-Mild, Systemic: Nausea-Mmild, Additional Details: After patient received vaccination she felt slightly dizzy and nauseous. Monitored pts bp and she was in  the normal range. She sat for about 15 min and she felt better. She left after she came back to normal. Followed up with the patient 3 hours later and she is okay',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.NitromecffffText: uncontrolled shaking of hands and arms; Chills; This spontaneous case was reported by a consumer and describes the occurrence of TREMOR (uncontrolled shaking of arms) and CHILLS (Chills) in a 95-year-old male patient who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.     No Medical History information was reported.    On 17-Jun-2021',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: fast heartbeat; dizziness; weakness; fever; soreness in arm; This spontaneous case was reported by a consumer and describes the occurrence of HEART RATE INCREASED (fast heartbeat), DIZZINESS (dizziness), ASTHENIA (weakness), MYALGIA (soreness in arm) and PYREXIA (fever) in a 78-year-old female patient who received',
#  'Order the symptoms in chronological order based on the timeline implied in the reference text. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: lower back aches; pain radiates from her lower back down to her pelvis; pain radiographates from his lower back up to  her buttocks; feels like a needle is pricking her and her right deltoid area where she received the vaccine; body aches over her whole body; Fever; This spontaneous case was reported by a consumer and describes the occurrence of BACK PAIN (lower back ac',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine their temeline for each symptom.Nitrome¯¯¯¯Text: couldn't move her arm; tried to move and it´s hurt; really bad hurt inside the injection site, in lthe eft arm; little soreness; This spontaneous case was reported by a consumer and describes the occurrence of PAIN (little soreness), MOBILITY DECREASED (couldn't move its arm), PAIN IN EXTREMITY (triedto move, and it`",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: whole face swelled up; lips swollen up; This spontaneous case was reported by a consumer and describes the occurrence of SWELLING FACE (whole face switched up) and LIP SWEILLING (lips swollen up) in a 67-year-old male patient who received mRNA-1273 (Moderna COVID-19 Vaccine) (batch nos. 00TFU4, 031A21',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the optimal order for each symptom.Nitrome¯¯¯¯Text: ?Moderna COVID?19 Vaccine EUA?  Headaches and body aches and injection site pain from 4:30 pm to 10 pm 12/29 Fever started at 10 pm 101 - Fever 103 at some point early morning - took Tylenol at 8 am 12/30 At 11 am, very bad chills and body shaking, uncontrollable Took a hot shower and tried to get under',
#  "Order the symptoms in chronological order based on the timeline implied in the-text. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: This spontaneous case was reported by a consumer and describes the occurrence of COVID-19 (Tested positive for COVID- 19 after first dose), FATIGUE and PRODUCT DOSE OMISSION ISSUE in an 82-year-old male patient who received mRNA-1273 (MODERNA COVID-2019 Vaccine) (batch no. 004M20A) for COVID19 vaccination.     The patient's past medical history",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine  timelines for each symptom.¯¯¯¯¯¯¯¯Text: The injection was VERY painful and (according to the nurse at the second injection) was given in  the wrong part of the arm - the front-facing  part ofthe arm rather than the side. It was also suggested that she hit a nerve because later that day and for several weeks after I would have pain in that upper muscle, moving horizontally around the muscle',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the optimal order for each symptom.Nitrome¯¯¯¯Text: I began getting aching in my right ankle. I was concerned that I had a blood clot. I went to the doctor, and they sent me to a hospital to have a doppler done to be tell whether there was one. That was negative. There was aching and numbness in  the right calf, from the foot to knee has numbness in it. The doctor',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the exact chronological order for each symptom.Nitrome¯¯¯¯Text: Inflamed injection site; Rash at injection site, Unable to lay on injection arm; Really sore arm; This spontaneous case was reported by a consumer and describes the occurrence of VACCINATION SITE INFLAMMATION (Inflamed Injection site), LIMB DISCOMFORT (Unable to Lay on injection Arm), PAIN IN EXTREMITY (Really sore arm) and VACCin',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: A couple months after my vaccination with the second dose, I began to experience my field of vision being blurred and did not associate them with a migraine at the first. Then it began more frequent and the doctor wanted me to log when I would get these. This gave me a dizziness as well extremely bad. Propranolol was given to help offset these migraines and dizziness',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the optimal order for each symptom.Nitrome¯¯¯¯Text: "COVID arm"/ "COVID rash".  Arm was red and warm to the skin on days 14 & 15 after vaccination (mild itching that required rubbing rather than scratching was also present). By the morning of Day 16 redness/heat had disappeared. Benadryl topical itch relief was applied on days14 & 15.NitromecffffSymptoms: [\'Erythema\', \'Prur',
#  'Order the symptoms in chronological order based on the timeline implied in the present text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Dry itchy red spots on buttocks; sore right where they gave me the shot; Red rash on Buttocks/rash higher up on to the right side of my behind; This spontaneous case was reported by a consumer and describes the occurrence of RASH ERYTHEMATOUS (Red rash in Buttocks, and/or skin rash/shoulder/arm/hand), RASH',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the optimal\xa0timeline for each symptom.Nitrome¯¯¯¯Text: Got the vaccine at 5:03 waited in a clinic for 15 min and left at about 5:27 started feeling throat swelling and numbness in my right side of the face. Got home at 5-35 called a Doctor and He told me to take Benadryl 50mg. Took it and 5-6 min I felt the swelling went down.NitromecffffSymptoms:',
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the exact duration of each symptom.NitromeNitromeText: After receiving the dose of Moderna, later that evening injection site became red, hot and hard. During the next day started to have headache, chills, shortness of breath, fatigue and body aches. Prior to getting COVID vaccine was having issues with breathing and contacted PCP on 1/23. She then came in to get shot on 1.25. Was seen by PCP and 1/29',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that time for each symptom.¯¯¯¯¯¯¯¯Text: Burning and discomfort; Burning and comfort; This spontaneous case was reported by a consumer and describes the occurrence of BURNING SENSATION (Burning and discomfort) and DISCOMFORT (Burned and discomfort), in a 68-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.     No medical history provided by the reporter.  Concomitant products included',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine  timelines for each symptom.ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¯¯¯¯Text: Large inflamed  red welts   that that begin with extremely bad itching all over body.... At first it was just on my torso, but now it  has spread to my legs and face. I am treating it with increased dosages of antihistamines , hydrocortisone cream, and  oatmeal lotion.  It flares up randomly.¯¯¯¯¯¯¯¯Symptoms: ['Erythema',",
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine and then repeat each symptom.Nitrome¯¯¯¯Text: Flu like symptoms, fever, chills, then a rash broke out all over his body.  It didn't itch, it hurt when something was dragged over it, like a finger or clothing.  There was deep, deep red and some parts of his body there was no regular skin showing.  Took him to ER, where tests were run, showing his liver counts were way off.  Biopsy was ",
# ...
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: 10 minutes after receiving 2nd dose of moderna covid Vaccine patient complained about itching and burning at and near site of injection.  Her arm was red from scratching. Patient denied any reaction for first dose of vaccine. Patient refused and SOB or swelling around eyes nose or mouth. Patient denial and itching in mouth or throat or any other site besides site of Injection. Patient was offered benadryl for local itching ',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: Describes feeling \'weird".  dizzy, slightly SOB, felt large lump in back of throat- felt similar to when she has experienced an allergic reaction.  she did not report it to observers but later reported to me after arriving home and still not feeling 100% back to baseline.  She stayed in observation area for 40 minutes post vaccine.  Reports that she',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that time for each symptom.¯¯¯¯¯¯¯¯Text: 2 days after vaccination, patient had upper lip swelling, swelling of the upper gums in mouth, itchiness, and a rash on both wrists. He took prednisone, Benadryl, and Pecpid and this resolved.  Then, 3 days after this (5 days after injection), the patient had right eye swelling.  He then tried prednisone and Claritin and ',
#  'Order the symptoms in chronological order based on the timeline implied in the original text. Think step by step to determine  timelines for each symptom.ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¯¯¯¯Text: syncope, vagal response, BP readings 52/33mmHg HR 56, 50/32mmHg HR 46, and 97/78mmHg HR 75.  Never lost consciousness but was sweating profusely and vomited.  Elevated feet, cool compress and ice to forehead and back of neck, monitored BP/HR and consciousness level.   EMS contacted, arrived  and assessed pt, concluded vagal  response,',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical scenario. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Feeling unwell; a continued and worsening cough; low grade fever 100.2; This spontaneous case was reported by a patient and describes the occurrence of MALAISE (Feeling unwell), COUGH (a continued and worsened cough) and PYREXIA (low grade fever100.2) in a 46-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine)',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Stomach ache; Headache; This spontaneous case was reported by a consumer and describes the occurrence of ABDOMINAL PAIN UPPER (Stomach acheal) and HEADACHE (Headache) in an adult female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.    Co-suspect product included non-company product ADALIMU',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the correct chronological order for each symptom.¯¯¯¯¯¯¯¯Text: injection sight (left arm) started out with just a little red spot (about the size of a quarter). A few days later it started to get bigger (about 25%) and the skin was hot and itchy. It started then got bigger (size of soft ball) and then slowly stopped to go down. Then onthe 18th, it increased double in size and is very itchy',
#  'Order the symptoms in chronological order based on the timeline implied in the-text. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: This spontaneous case was reported by a consumer and describes the occurrence of VACCINATION SITE MOVEMENT IMPAIRMENT, RASH, VaccINATION SPOT PAIN, VINCINATION SEITE PAIN and VACCinATION Site RASH in a 59-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) (batch no. 033B',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that time for each symptom.¯¯¯¯¯¯¯¯Text: Starting around 11 am the next day (4/10) after receiving the vaccine, pt. states noticed left upper arm pain, redness, bruising and warm to touch.  Pt. states also started 'feeling bad' and complained of nausea, body aches, fever, chills and headache. Pt. called to report symptoms to nurse on 4/13 - states was feeling better but ",
#  'Order the symptoms in chronological order based on the timeline implied in the clinical scenario. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Headache, HYPERtension & Tachycardia Narrative:  Pt received 3rd dose of Moderna vaccine on 10/28/21 at 6pm. By 6am the following day, pt was complaining of severe headaches that started at the bottom of the head and radiated down the neck. No NSAIDs given at that point. Vitals at 0930: BP 124',
#  "Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.NitromeNitromeText: Moderna Covid-19 Vaccine EUA 10 days after receiving the 1st vaccine, I developed a rash below the injection site which was about 4-5 in. in diameter.  It was warm to touch and itchy.  Also felt small lump under the skin.  I had no fever and no other symptoms.¯¯¯¯¯¯¯¯Symptoms: ['Injection site mass', 'Injection",
#  'Order the symptoms in chronological order based on the timeline implied in the-text. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: felt bad; Stuck in bed; This spontaneous case was reported by a consumer and describes the occurrence of FEELING ABNORMAL (felt bad) and MALAISE (Stuck in Bed) in a female patient of an unknown age who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination.     No Medical History information was reported.    On 26-Feb-20',
#  "Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine this theory for each symptom.Nitrome¯¯¯¯Text: Presented 2/5/22 to the ED for profound weakness, unable to stand or ambulate.In the emergency room patient's temperature was a 100.4°, heart rate 76, blood pressure 132/76 initially his O2 sat was on a present on room air.  Shortly afterwards it dropped down to 90% on room room.  He has no 94% on 2 L nasal cannula.",
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that time for each symptom.¯¯¯¯¯¯¯¯Text: Lethargic; Mild flu like symptoms; Chills; Muscle aches; This spontaneous case was reported by a consumer and describes the occurrence of LETHARGY (Lethargic), INFLUENZA LIKE ILLNESS (Mild flu like Symptoms), CHILLS (Chills) and MYALGIA (Muscle aches) in a patient of an unknown age and gender who received mRNA-',
#  'Order the symptoms in chronological order based on the timeline implied in the following text. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: About a week or 2 after receiving the 2nd Moderna COVID-19 vaccine, I began having episodes of bradycardia with lightheadedness and heaviness/pressure in my chest and bilateral sides of my neck followed by tachycardic with multi focal PVCs. My heart rate has been as low as 36 bpm and as high as 170-180 bpm. I was seen',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine  timelines for each symptom.Nitrome¯¯¯¯Text: Fever started after 12 hours.  Lasted 48 hours ranging from 100-103.1 Body aches and "nerve type pain".  Aches even without movement  and pain with things touching the skin.  Started 12 hours after injection and lasted 48 hours. Headache started 24 hours after Injection and lasted48 hours¯¯¯¯¯¯¯¯Symptoms: [\'Headache\', \'Neuralgia\', \'Pain\', \'Py',
#  'Order the symptoms in chronological order based on the timeline implied in the present case report. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: rashes on chest/ rashes on abdomen/ rashes in back/rashes on neck; Headache; chills; had a fever of 99.7; legs hurting,arms hurting; back hurting; This spontaneous case was reported by a consumer and describes the occurrence of PAIN IN EXTREMITY (legs hurting, forearms hurting), BACK PAIN (back hurting), RASH (rashes On chest/ashes on abdomen /',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: I had a fever - it came and went. The highest was 103. I had congestion, runny nose, body aches and it was two days of fever on/off. The rest of symptoms lingered for a few days. The cough came on that 3rd day and that lingering for a week longer than the other symptoms. I took a rapid test',
#  "Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the\xa0timeline for each symptom.¯¯¯¯¯¯¯¯Text: 1 week plus 1 day post vaccination my Left arm started to itch near the injection site and a red rash developed about 3 inch x 1 inch in size slightly below the actual injection point - it is still itchy and red  my face also feels slightly flushed on and offÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¯¯¯¯Symptoms: ['Flushing', 'Injection site erythema', 'injection site pruritus', ' Injection site rash",
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.¯¯¯¯¯¯¯¯Text: Vaccination site warmth; Vaccination side effects; Vaccinations site pruritus; Vaccinia site erythema; Vaccinating site swelling; Vaccinated site pain; This spontaneous case was reported by a consumer and describes the occurrence of VACCINATION SITE WARMTH (Vaccination site warm), VACCinATION Site PRURITUS (Vacination site pruritus), VaccINATION SSTITE',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the correct chronological order for each symptom.Nitrome¯¯¯¯Text: Narrative: Per PCP note in system: "He had second moderna [vaccine] on Monday and when he had the first shot he was asked to stay due to allergy from wasp bite. First shot he felt lightheaded. {with the second dose of vaccine,] They did not keep him more than 15 min and he felt same as last time. He thought he had',
#  'Order the symptoms in chronological order based on the timeline implied in the following text. Think step by step to determine the specific symptom and then proceed with each symptom.NitromeNitromeText: a ain in their left arm,from the elbowto their fingers, like numbling sensation,like one hits bone on their elbow,like pnched nerve pain,And now they are feeling the same on two opposite arm; a pain in that left arm. From the elbows, like a numbing sensation, like when one hits the bone onthe elbow',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: Rash & swelling.  Received vaccine at 10:00a this morning.  Site was mildly sore but that greatly increased from 5:30p-7:30PM and hasn?t improved.  Applied heat a couple times with a bean bag warmed in  the microwave.  Was getting ready for bed at 10-00p and noticed the rash.  I hadn?t looked at',
#  "Order the symptoms in chronological order based on the timeline implied in the present text. Think step by step to determine the duration for each symptom.¯¯¯¯¯¯¯¯Text: Beginning of Alzheimer; Not feeling well / just not been feeling well; Fatigue; Head ache; This spontaneous case was reported by a consumer and describes the occurrence of DEMENTIA ALZHEIMER'S TYPE (Beginning of Alzheimer) in a 79-year-old female patient who received mRNA-1273 (Moderna COVID-19 Vaccine) for COVID- 19 vaccination. The occurrence of additional non-serious",
#  'Order the symptoms in chronological order based on the timeline implied in the paper. Think step by step to determine the optimal order for each symptom.Nitrome¯¯¯¯Text: Basically, a week from the day of my first Moderna injection that evening I noticed my arm was itchy, then I felt bumps...I looked in  the mirror and it looked like I had gotten bitten multiple times by a mosquito...I researched online that this happens sometimes, so I took some Tylenol and went to bed. The next day, the bumps had gone down',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine the correct\xa0timeline for each symptom.Nitrome¯¯¯¯Text: On Thursday, I noticed bilateral redness on my arms onthe inner aspect of elbow. I thought it was chapped skin or from a too-hot shower.  On Friday afternoon, the redness was more pronounced and it had spread to the bicep/ tricep area. It looked like a viral rash and the reddest part was still the inner aspects of the elbow',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that time for each symptom.Nitrome¯¯¯¯Text: Pain onthe back; Vomit; Severe pain in  the stomach; Constipated; This spontaneous case was reported by a consumer and describes the occurrence of ABDOMINAL PAIN UPPER (Severe pain in\xa0the stomach), CONSTIPATION (Constipated), BACK PAIN (Pain on\xa0the back) and VOMITING (Vomit) in a 61-year-old female',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine that time for each symptom.¯¯¯¯¯¯¯¯Text: left arm painful/arm pain was so bad I went to the Emergency Room to have this looked at; injection site blue and purple; swollen Lymph nodes; injection sites is swollen; headaches; nausea; fatigue; This spontaneous case was reported by a consumer (subsequently medically confirmed) and describes the occurrence of VACCINATION SITE SWELLING (injection site is swollen), VACCinATION',
#  'Order the symptoms in chronological order based on the timeline implied in the clinical text. Think step by step to determine the\xa0timeline for each symptom.Nitrome¯¯¯¯Text: I was very tired the night of the shot with chills started at 8:00pm on 4/1/21.  On 4/2/21 around 7:00am I started vaginal bleeding. (I got my period.  I was not due to get this at this time.  This also happened after my 1st vaccine on 3/31.  Prior ',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0text. Think step by step to determine that the chronological order for each symptom.Nitrome¯¯¯¯Text: 1130 am Thursday 2/4 shot #2, no effects, less pain than #1 8 pm Thursday increased pain at surgical incision sites from my gallbladder which I was 3 weeks post-surgery, body aches, chills, mild fever, fatigue, sore arm 11pm headache, body Aches, dizziness, continued, chills and fever 2am chills gone but sweats, sore throat, extreme fatigue,',
#  'Order the symptoms in chronological order based on the timeline implied in the\xa0 text. Think step by step to determine the exact order for each symptom.Nitrome¯¯¯¯Text: Day 1-4 significant lymph node swelling (arm pit), significant arm pain and fatigue followed  by  day 5-9 of dizzyness/vertigo, extreme fatigue, nausea, arm/leg tingling , intermittent shaking/chills but not fever, significant anxiety.  Went to urgent care  on day 5 7/22 and received 1 L NS fluid bolus, CBC/BMP labs checked, pregnancy ']

# %%
## TODO: Need to convert this to CSV
eval_df_wpeft.to_csv(os.path.join(results_dir, f'{model_name}-results.csv'), index=False)

# %% [markdown]
# ### Inference Using BioBART with PEFT:

# %%
# Step 1: Load the pre-trained PEFT model
peft_model = PeftModel.from_pretrained(base_model, peft_model_path, is_trainable=False)

## Step 2: Perform batch inference using the loaded model
predicted_sequence_peft = batch_inference(peft_model, tokenizer, test_dataset['input_text'].to_list())

## Step 3: Create a DataFrame for evaluation
eval_df_peft = create_eval_df(test_dataset, predicted_sequence_peft)
eval_df_peft[['symptom_text', 'true_sequence', 'predicted_sequence']].head(10)
# Out:
# Processed Batch: 0 successfully!!
# Processed Batch: 1 successfully!!
# Processed Batch: 2 successfully!!
# Processed Batch: 3 successfully!!
# Processed Batch: 4 successfully!!
# Processed Batch: 5 successfully!!
# Processed Batch: 6 successfully!!
# Processed Batch: 7 successfully!!
# Processed Batch: 8 successfully!!
# Processed Batch: 9 successfully!!
# Processed Batch: 10 successfully!!
# Processed Batch: 11 successfully!!
# Processed Batch: 12 successfully!!
# Processed Batch: 13 successfully!!
# Processed Batch: 14 successfully!!
# Processed Batch: 15 successfully!!
# Processed Batch: 16 successfully!!
# Processed Batch: 17 successfully!!
# Processed Batch: 18 successfully!!
# Processed Batch: 19 successfully!!
# Processed Batch: 20 successfully!!
# Processed Batch: 21 successfully!!
# Processed Batch: 22 successfully!!
# Processed Batch: 23 successfully!!
# Processed Batch: 24 successfully!!
# Processed Batch: 25 successfully!!
# Processed Batch: 26 successfully!!
# Processed Batch: 27 successfully!!
# Processed Batch: 28 successfully!!
# Processed Batch: 29 successfully!!
# Processed Batch: 30 successfully!!
# Processed Batch: 31 successfully!!
# Processed Batch: 32 successfully!!
# Processed Batch: 33 successfully!!
# Processed Batch: 34 successfully!!
# Processed Batch: 35 successfully!!
# Processed Batch: 36 successfully!!
# Processed Batch: 37 successfully!!
# Processed Batch: 38 successfully!!
# Processed Batch: 39 successfully!!
# Processed Batch: 40 successfully!!
# Processed Batch: 41 successfully!!
# Processed Batch: 42 successfully!!
# Processed Batch: 43 successfully!!
# Processed Batch: 44 successfully!!
# Processed Batch: 45 successfully!!
# Processed Batch: 46 successfully!!
# Processed Batch: 47 successfully!!
# Processed Batch: 48 successfully!!
# Processed Batch: 49 successfully!!
# Processed Batch: 50 successfully!!
# Processed Batch: 51 successfully!!
# Processed Batch: 52 successfully!!
# Processed Batch: 53 successfully!!
# Processed Batch: 54 successfully!!
# Processed Batch: 55 successfully!!
# Processed Batch: 56 successfully!!
# Processed Batch: 57 successfully!!
# Processed Batch: 58 successfully!!
# Processed Batch: 59 successfully!!
# Processed Batch: 60 successfully!!
# Processed Batch: 61 successfully!!
# Processed Batch: 62 successfully!!
# Processed Batch: 63 successfully!!
# Processed Batch: 64 successfully!!
# Processed Batch: 65 successfully!!
# Processed Batch: 66 successfully!!
# Processed Batch: 67 successfully!!
# Processed Batch: 68 successfully!!
# Processed Batch: 69 successfully!!
# Processed Batch: 70 successfully!!
# Processed Batch: 71 successfully!!
# Processed Batch: 72 successfully!!
# Processed Batch: 73 successfully!!
# Processed Batch: 74 successfully!!
# Processed Batch: 75 successfully!!
# Processed Batch: 76 successfully!!
# Processed Batch: 77 successfully!!
# Processed Batch: 78 successfully!!
# Processed Batch: 79 successfully!!
# Processed Batch: 80 successfully!!
# Processed Batch: 81 successfully!!
# Processed Batch: 82 successfully!!
# Processed Batch: 83 successfully!!
# Processed Batch: 84 successfully!!
# Processed Batch: 85 successfully!!
# Processed Batch: 86 successfully!!
# Processed Batch: 87 successfully!!
# Processed Batch: 88 successfully!!
# Processed Batch: 89 successfully!!
# Processed Batch: 90 successfully!!
# Processed Batch: 91 successfully!!
# Processed Batch: 92 successfully!!
# Processed Batch: 93 successfully!!
# Processed Batch: 94 successfully!!
# Processed Batch: 95 successfully!!
# Processed Batch: 96 successfully!!
# Processed Batch: 97 successfully!!
# Processed Batch: 98 successfully!!
# Processed Batch: 99 successfully!!
#                                         symptom_text  \
# 0  A few days after my vaccine, I noticed under t...
# 1  Period schedule on and off the chart; Increase...
# 2  within 24 hours of receiving my 2nd dose, I fi...
# 3  Side effects seem to have cleared up by the 17...
# 4  I received my first Moderna vaccine on one/14/...
# 5  Patient experienced only chills; Fever; Sorene...
# 6  8 days after the first vaccine dose, I had itc...
# 7  Sore arm; Very tired; Headache; Burning sensat...
# 8  Chills; Urinating (More often); This spontaneo...
# 9  Swelling Left arm, upper Calves and legs swell...
#
#                                        true_sequence  \
# 0                                [Blister, Erythema]
# 1  [Menstrual disorder, Heavy menstrual bleeding,...
# 2  [Pyrexia, Chills, Headache, Myalgia, Neuralgia...
# 3               [Vaccination complication, Headache]
# 4  [Lymphadenopathy, Arthralgia, Pain in extremit...
# 5                         [Chills, Pyrexia, Myalgia]
# 6  [Injection site pruritus, Injection site swell...
# 7  [Burning sensation, Headache, Pain in extremit...
# 8                              [Chills, Pollakiuria]
# 9  [Peripheral swelling, Vaccination site bruisin...
#
#                                   predicted_sequence
# 0                                [Erythema, Blister]
# 1  [Menstrual disorder, Heavy menstrual bleeding,...
# 2  [Pyrexia, Chills, Headache, Myalgia, Neuralgia...
# 3               [Vaccination complication, Headache]
# 4  [Lymphadenopathy, Menstrual disorder, Amenorrh...
# 5                         [Chills, Pyrexia, Myalgia]
# 6  [Injection site pruritus, Injection site swell...
# 7  [Pain in extremity, Burning sensation, Headach...
# 8                              [Chills, Pollakiuria]
# 9  [Peripheral swelling, Vaccination site bruisin...

# %%
eval_df_peft.to_csv(os.path.join(results_dir, f'{model_name}-peft-results.csv'), index=False)
