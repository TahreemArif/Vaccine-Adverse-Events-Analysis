# %%
import os
import pandas as pd
import numpy as np

from ast import literal_eval
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Mounted at /content/drive

# %%
base_dir = '/content/drive/MyDrive/NLP/vaers_analysis'
data_dir = os.path.join(base_dir, 'data')
results_dir = os.path.join(base_dir, 'results')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
## Load the clean vaers data for COVID-19 Moderna
vaers_data = pd.read_csv(os.path.join(data_dir, 'vaers_data.csv'))
vaers_data['symptoms'] = vaers_data['symptoms'].apply(literal_eval)
vaers_data['ordered_symptoms'] = vaers_data['ordered_symptoms'].apply(literal_eval)

## Randomly sample 10,000 Ordered Symptoms for Associative Analysis
data = vaers_data['ordered_symptoms'].sample(n=10000, random_state=42)

data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 67770     [Pain in extremity, Influenza like illness, Ar...
# 226924                                 [Rash macular, Rash]
# 123500                            [Diarrhoea, Nausea, Pain]
# 39400     [Anaphylactic reaction, Dyspnoea, Chest discom...
# 249744    [COVID-19, SARS-CoV-2 test positive, Vaccine b...
# Name: ordered_symptoms, dtype: object

# %%
data = data.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Initialize the TransactionEncoder
transaction_encoder = TransactionEncoder()
binary_matrix = transaction_encoder.fit(data).transform(data)
binary_df = pd.DataFrame(binary_matrix, columns=transaction_encoder.columns_)
binary_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Abdominal X-ray  Abdominal abscess  Abdominal discomfort  \
# 0            False              False                 False
# 1            False              False                 False
# 2            False              False                 False
# 3            False              False                 False
# 4            False              False                 False
# 5            False              False                 False
# 6            False              False                 False
# 7            False              False                 False
# 8            False              False                 False
# 9            False              False                 False
#
#    Abdominal distension  Abdominal exploration  Abdominal infection  \
# 0                 False                  False                False
# 1                 False                  False                False
# 2                 False                  False                False
# 3                 False                  False                False
# 4                 False                  False                False
# 5                 False                  False                False
# 6                 False                  False                False
# 7                 False                  False                False
# 8                 False                  False                False
# 9                 False                  False                False
#
#    Abdominal mass  Abdominal pain  Abdominal pain lower  Abdominal pain upper  \
# 0           False           False                 False                 False
# 1           False           False                 False                 False
# 2           False           False                 False                 False
# 3           False           False                 False                 False
# 4           False           False                 False                 False
# 5           False           False                 False                 False
# 6           False           False                 False                 False
# 7           False           False                 False                 False
# 8           False           False                 False                 False
# 9           False           False                 False                 False
#
#    ...  Wound  Wound dehiscence  Wound infection pseudomonas  Wound treatment  \
# 0  ...  False             False                        False            False
# 1  ...  False             False                        False            False
# 2  ...  False             False                        False            False
# 3  ...  False             False                        False            False
# 4  ...  False             False                        False            False
# 5  ...  False             False                        False            False
# 6  ...  False             False                        False            False
# 7  ...  False             False                        False            False
# 8  ...  False             False                        False            False
# 9  ...  False             False                        False            False
#
#    Wrong technique in product usage process  X-ray abnormal  \
# 0                                     False           False
# 1                                     False           False
# 2                                     False           False
# 3                                     False           False
# 4                                     False           False
# 5                                     False           False
# 6                                     False           False
# 7                                     False           False
# 8                                     False           False
# 9                                     False           False
#
#    X-ray dental normal  X-ray limb  Xanthopsia  Yellow skin
# 0                False       False       False        False
# 1                False       False       False        False
# 2                False       False       False        False
# 3                False       False       False        False
# 4                False       False       False        False
# 5                False       False       False        False
# 6                False       False       False        False
# 7                False       False       False        False
# 8                False       False       False        False
# 9                False       False       False        False
#
# [10 rows x 2151 columns]

# %%
## Calculate Support
support_df = apriori(binary_df, min_support=0.01, use_colnames=True, verbose=1)
sorted_support_df = support_df.sort_values('support', ascending=False)
sorted_support_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Processing 30 combinations | Sampling itemset size 5
#      support                   itemsets
# 23    0.2163                 (Headache)
# 54    0.1968                  (Pyrexia)
# 18    0.1886                  (Fatigue)
# 8     0.1709                   (Chills)
# 48    0.1526                     (Pain)
# 45    0.1155                   (Nausea)
# 49    0.1113        (Pain in extremity)
# 44    0.0973                  (Myalgia)
# 102   0.0940          (Chills, Pyrexia)
# 31    0.0898      (Injection site pain)
# 14    0.0898                (Dizziness)
# 29    0.0873  (Injection site erythema)
# 144   0.0853        (Headache, Pyrexia)
# 95    0.0837         (Headache, Chills)
# 126   0.0831        (Headache, Fatigue)
# 5     0.0755                 (COVID-19)
# 0     0.0747               (Arthralgia)
# 94    0.0701          (Chills, Fatigue)
# 134   0.0681         (Fatigue, Pyrexia)
# 53    0.0678                 (Pruritus)

# %%
## Calculate 60% Confidence
conf_df = association_rules(support_df, metric="confidence", min_threshold=0.5, num_itemsets=len(binary_df))
conf_df = conf_df[['antecedents', 'consequents', 'confidence']]
sorted_conf_df = conf_df.sort_values('confidence', ascending=False)
sorted_conf_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                           antecedents  \
# 2                    (Vaccine breakthrough infection)
# 19                  (SARS-CoV-2 test positive, Cough)
# 0                          (SARS-CoV-2 test positive)
# 20                                  (COVID-19, Cough)
# 1                                          (COVID-19)
# 68   (Injection site warmth, Injection site swelling)
# 67   (Injection site warmth, Injection site pruritus)
# 65  (Injection site pruritus, Injection site swell...
# 59                               (Headache, Vomiting)
# 9                             (Injection site warmth)
# 5                         (Injection site induration)
# 6                           (Injection site pruritus)
# 53                                (Fatigue, Vomiting)
# 42                                 (Chills, Vomiting)
# 73                     (Headache, Chills, Arthralgia)
# 74                    (Headache, Arthralgia, Pyrexia)
# 7                           (Injection site swelling)
# 88                         (Fatigue, Nausea, Pyrexia)
# 64       (Injection site warmth, Injection site pain)
# 61     (Injection site pruritus, Injection site pain)
#
#                    consequents  confidence
# 2                   (COVID-19)    0.950820
# 19                  (COVID-19)    0.939850
# 0                   (COVID-19)    0.935737
# 20  (SARS-CoV-2 test positive)    0.919118
# 1   (SARS-CoV-2 test positive)    0.790728
# 68   (Injection site erythema)    0.778281
# 67   (Injection site erythema)    0.777778
# 65   (Injection site erythema)    0.764493
# 59                    (Nausea)    0.726804
# 9    (Injection site erythema)    0.724832
# 5    (Injection site erythema)    0.706587
# 6    (Injection site erythema)    0.705882
# 53                    (Nausea)    0.695364
# 42                    (Nausea)    0.683908
# 73                   (Pyrexia)    0.679739
# 74                    (Chills)    0.666667
# 7    (Injection site erythema)    0.665663
# 88                    (Chills)    0.662500
# 64   (Injection site erythema)    0.662252
# 61   (Injection site erythema)    0.650273

# %%
## Calculate Lift
lift_df = association_rules(support_df, metric="lift", min_threshold=1.001, num_itemsets=len(binary_df))
lift_df = lift_df[['antecedents', 'consequents', 'lift']]
sorted_lift_df = lift_df.sort_values('lift', ascending=False)
sorted_lift_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                            antecedents  \
# 256                         (SARS-CoV-2 test positive)
# 253                                  (COVID-19, Cough)
# 33                                          (COVID-19)
# 32                    (Vaccine breakthrough infection)
# 252                  (SARS-CoV-2 test positive, Cough)
# 257                                         (COVID-19)
# 30                          (SARS-CoV-2 test positive)
# 31                                          (COVID-19)
# 94                                         (Skin warm)
# 95                                          (Erythema)
# 563                          (Injection site erythema)
# 558   (Injection site warmth, Injection site swelling)
# 557                          (Injection site erythema)
# 552   (Injection site warmth, Injection site pruritus)
# 546  (Injection site pruritus, Injection site swell...
# 551                          (Injection site erythema)
# 561                            (Injection site warmth)
# 560  (Injection site swelling, Injection site eryth...
# 567                            (Injection site warmth)
# 566  (Injection site pruritus, Injection site swell...
#
#                                            consequents       lift
# 256                                  (COVID-19, Cough)  14.406233
# 253                         (SARS-CoV-2 test positive)  14.406233
# 33                    (Vaccine breakthrough infection)  12.593638
# 32                                          (COVID-19)  12.593638
# 252                                         (COVID-19)  12.448339
# 257                  (SARS-CoV-2 test positive, Cough)  12.448339
# 30                                          (COVID-19)  12.393863
# 31                          (SARS-CoV-2 test positive)  12.393863
# 94                                          (Erythema)   9.245123
# 95                                         (Skin warm)   9.245123
# 563   (Injection site warmth, Injection site swelling)   8.915012
# 558                          (Injection site erythema)   8.915012
# 557   (Injection site warmth, Injection site pruritus)   8.909253
# 552                          (Injection site erythema)   8.909253
# 546                          (Injection site erythema)   8.757076
# 551  (Injection site pruritus, Injection site swell...   8.757076
# 561  (Injection site swelling, Injection site eryth...   8.705599
# 560                            (Injection site warmth)   8.705599
# 567  (Injection site pruritus, Injection site swell...   8.591901
# 566                            (Injection site warmth)   8.591901

# %%
sorted_support_df.to_csv(os.path.join(results_dir, 'support_score.csv'), index=False)
sorted_conf_df.to_csv(os.path.join(results_dir, 'confidence_score.csv'), index=False)
sorted_lift_df.to_csv(os.path.join(results_dir, 'lift_score.csv'), index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
